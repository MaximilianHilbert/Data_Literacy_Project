# %% [markdown]
# # Rental price analysis of german cities
# __Creating and Altering Dataframes__ \
# __by Maximilian Hilbert__

# %%
import re
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
from numpy import savetxt

# %% [markdown]
# __For later use__

# %% [markdown]
# Source for inflation data: https://de.statista.com/statistik/daten/studie/1046/umfrage/inflationsrate-veraenderung-des-verbraucherpreisindexes-zum-vorjahr/ \
# Source for ratio of inflation caused by rentals: https://service.destatis.de/Voronoi/PreisKaleidoskop.svg

# %%
def inflation_adjustment(inflation,means_raw):
    ret_lst=[]
    for idx in range(len(means_raw)):
        z=1
        value=means_raw[idx]
        for i in range(idx):
            z*=1/inflation[i]
        adjusted_value=z*value
        ret_lst.append(adjusted_value)
    return ret_lst

# %%
#inflation adjustment and correction for rental housing
correction_factor=0.8
infl_raw=[1.1,2.1,2,1.4,1,0.5,0.5,1.5] #in %
infl_lst_full=[1.011,1.021,1.02,1.014,1.01,1.005,1.005,1.015] #final factors
infl_lst_part=[1+(x*correction_factor/100) for x in infl_raw]

infl_lst_2002_2017=[1.013,1.011,1.017,1.015,1.016,1.023,1.026,1.003,1.011,1.021,1.02,1.014,1.01,1.005,1.005,1.015]

# %% [markdown]
# __Part 1 - Alter .html files for each city by http://www.wohnung.com/mietpreise__

# %% [markdown]
# __For easier use, we clean off all whitespace characters like /n, /t and /s out of each .html-file__

# %%
files=os.listdir("data\\raw_files")

# %%
def cleaning_html():
    #for each .html file in the subdirectory
    for i in tqdm(range(len(files))):
        filename=files[i]
        #read data out of file
        with open("data\\raw_files\\"+filename, "r", encoding="utf-8") as file:
            text=file.read()
            file.close()
        #delete all whitespaces
        new_text=re.sub("\s+", "", text)
        #save the "new" file
        with open("data\\raw_files\\"+filename, "w", encoding="utf-8") as file:
            file.write(new_text)
            file.close()
    return "Done."

# %%
cleaning_html()
# Out:
# 100%|██████████| 2469/2469 [00:02<00:00, 1077.29it/s]
# 'Done.'

# %% [markdown]
# __Now we are interested in looking at the content of each .html-file and we notice, that the data we want to get is contained in an java-script linechart, which we can extract by figuring out a suitable regex__

# %%
def create_dict_data():
    values={}
    #for each .html file in the subdirectory read contents
    for i in tqdm(range(len(files))):
        filename=files[i]
        file=open("data\\raw_files\\"+filename, "r", encoding="utf-8")
        text=file.read()
        try:
        #find all values that are between the "id=rentprice-development-linechart.js" and the end of the script
        #and get the first appearing value
            raw=re.findall("(?=id\=\"rentprice\-development\-linechart\-chartjs)(.*?)(?<=\<\/script\>)", text)[0]
        except IndexError:
        #if there is no second appearing entry an IndexError is being rased, if so, ignore that and progress 
            pass
        try:
            #in the raw string find all values that are between "data:[" and "]" that are seperated by a ","
            #and get the first appearing value
            data=re.findall("(?=data\:\[)([\S]*?)(?<=\,\])", raw)[0]
            #find all numerical values between "." (important, because there are some int values e.g. "9"
            # and floats like "9.89")
            data=re.findall("[0-9]+\.[0-9]+", data)
            #crop .html ending out of filename for convenience
            cityname=re.findall("(.*)(?=.html)",filename)[0]
            #save the values in a dictionary for easier use later
            values[cityname]=[float(x) for x in data]
        except TypeError:
            #Pass a specific error that occurs because of edge-cases
            pass
    return values

# %%
def create_dict_data():
    values={}
    for i in tqdm(range(len(files))):
        filename=files[i]
        file=open("data\\raw_files\\"+filename, "r", encoding="utf-8")
        text=file.read()
        try:
            raw=re.findall("(?=id\=\"rentprice\-development\-linechart\-chartjs)(.*?)(?<=\<\/script\>)", text)[0]
        except IndexError:
            pass
        try:
            data=re.findall("(?=data\:\[)([\S]*?)(?<=\,\])", raw)[0]
            data=re.findall("[0-9]+\.[0-9]+", data)
            #crop .html ending out of filename
            cityname=re.findall("(.*)(?=.html)",filename)[0]
            values[cityname]=[float(x) for x in data]
        except TypeError:
            pass
    return values

def changing_order(dict):
    for element in dict.values():
        while len(element)<16:
            element.insert(0, np.nan)
    return dict
    
dict_data=create_dict_data()
df_raw=pd.DataFrame.from_dict(changing_order(dict_data), orient="index")
# Out:
# 100%|██████████| 2469/2469 [00:44<00:00, 55.93it/s]

# %% [markdown]
# __Save dictionary in RAM__

# %%
dict_data=create_dict_data()
# Out:
# 100%|██████████| 2469/2469 [00:01<00:00, 2001.15it/s]

# %% [markdown]
# __Because there is a lack in data for some cities that have started collecting data later than others, we have to be sure, that the values are sorted in the correct order and values in the past (that are missing) will get filled with dummy values like NaN__

# %%
def changing_order(dict):
    #iterate through the dictionary of values
    for element in dict.values():
        #fill each dictionary entry until it has 16 values (reaching from 2002 to 2017)
        while len(element)<16:
            #insert NaNs if a value is equal to 0
            element.insert(0, np.nan)
    return dict

# %% [markdown]
# __Save cleaned data into pandas-dataframe__

# %%
df_raw=pd.DataFrame.from_dict(changing_order(dict_data), orient="index")

# %% [markdown]
# __Now we rename columns for convenience and make corrections of obviously wrong data__

# %%
def rename(dataframe):
    years=[x for x in range(2002, 2018)]
    #Some values are obviously wrong and equal to 0, we correct them by replacing them to NaN that averages and 
    #standard devs. dont get affected
    dataframe[dataframe.columns]=dataframe[dataframe.columns].replace(0.0, np.nan)
    #Renaming columns to corresponding years (would have been possible to do that by getting the labels out of the
    #java-script plot, but this way is easier)
    dataframe=dataframe.rename({0: years[0], 1: years[1], 0: years[0], 1: years[1],2: years[2], 3: years[3],4: years[4], 5: years[5],
                6: years[6], 7: years[7],8: years[8], 9: years[9],0: years[0], 10: years[10],11: years[11], 12: years[12],
                13: years[13], 14: years[14],15: years[15]}, axis=1)
    return dataframe

# %% [markdown]
# __Perform the first calulcations on the data in order to get the averages, standard dev. and the number of available datapoints per year__

# %%
def calc(dataframe):
    dataframe=dataframe.T
    dataframe["Mean in $\\mathrm{\\frac{EUR}{m^2}}$"]=dataframe.mean(skipna=True, axis=1)
    dataframe["SD in $\\mathrm{\\frac{EUR}{m^2}}$"]=dataframe.std(skipna=True, axis=1)
    dataframe["Historical data points"]=dataframe.count(axis=1)
    return dataframe

# %% [markdown]
# __Rename and calculate in one step__

# %%
df_calc=calc(rename(df_raw))

# %% [markdown]
# __Inflation adjustment__

# %%
df_copy=df_calc.copy()

# %%
df_copy["Mean in $\\mathrm{\\frac{EUR}{m^2}}$"]=inflation_adjustment(infl_lst_2002_2017,df_copy["Mean in $\\mathrm{\\frac{EUR}{m^2}}$"].values)

# %%
df_copy["SD in $\\mathrm{\\frac{EUR}{m^2}}$"]=inflation_adjustment(infl_lst_2002_2017,df_copy["SD in $\\mathrm{\\frac{EUR}{m^2}}$"].values)

# %%
df_copy=df_copy.round(2)

# %%
df_copy["..."]=["..." for x in range(len(df_copy))]

# %%
df_copy
# Out:
#       aach  aachen  aalen  aarbergen  abensberg  absberg  abstatt  achim  \
# 2002   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2003   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2004   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2005   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2006   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2007   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2008   NaN     NaN    NaN        NaN        NaN      NaN      NaN   6.10
# 2009  6.68     NaN   5.90        NaN        NaN      NaN      NaN    NaN
# 2010  5.14    6.95   6.10       5.20       4.53     4.72     7.11   5.64
# 2011  5.68    7.19   6.15       5.46       6.05     4.51     6.56   5.89
# 2012  5.97    7.63   6.39       5.17       5.81     5.19     7.34   6.21
# 2013  5.09    7.92   6.73       4.97       5.96     4.80     7.99   6.22
# 2014  6.53    8.16   7.12       5.13       5.93      NaN     7.81   6.29
# 2015  6.37    8.30   7.62       5.17       6.87     6.85     8.21   6.46
# 2016  6.69    8.64   8.38       5.60       8.01     6.56     8.94   6.96
# 2017  7.04    8.87   8.66       5.71       7.90     7.07     8.89   7.47
#
#       achtrup  adelschlag  ...  zuelpich  zusmarshausen  zweibruecken  \
# 2002      NaN         NaN  ...       NaN            NaN           NaN
# 2003      NaN         NaN  ...       NaN            NaN           NaN
# 2004      NaN         NaN  ...       NaN            NaN           NaN
# 2005      NaN         NaN  ...       NaN            NaN           NaN
# 2006      NaN         NaN  ...       NaN            NaN           NaN
# 2007      NaN         NaN  ...       NaN            NaN           NaN
# 2008      NaN         NaN  ...       NaN            NaN           NaN
# 2009      NaN         NaN  ...       NaN            NaN          4.58
# 2010     5.45         NaN  ...      5.27           5.55          4.88
# 2011     4.99         NaN  ...      5.35           5.72          4.93
# 2012     5.03        5.24  ...      5.30           6.00          5.10
# 2013     5.34        5.97  ...      5.47           6.33          5.07
# 2014     5.16        6.21  ...      5.66           6.17          5.14
# 2015     5.48        8.11  ...      5.69           6.08          5.27
# 2016     6.16        6.74  ...      6.01           7.51          5.39
# 2017     6.17        8.16  ...      6.14           7.68          5.71
#
#       zwenkau  zwickau  zwingenberg  Mean in $\mathrm{\frac{EUR}{m^2}}$  \
# 2002      NaN      NaN          NaN                                5.48
# 2003      NaN      NaN          NaN                                5.27
# 2004      NaN      NaN          NaN                                5.66
# 2005      NaN      NaN          NaN                                5.27
# 2006      NaN      NaN          NaN                                5.22
# 2007      NaN      NaN          NaN                                4.93
# 2008      NaN      NaN          NaN                                4.91
# 2009      NaN      NaN          NaN                                5.55
# 2010     5.02     4.80         7.62                                5.27
# 2011     4.97     4.84         7.50                                5.30
# 2012     5.03     4.93         7.26                                5.29
# 2013     5.19     4.99         7.92                                5.31
# 2014     5.40     5.09         8.01                                5.36
# 2015     5.35     5.10         7.92                                5.47
# 2016     5.59     5.23         7.77                                5.73
# 2017     6.29     5.43         8.66                                5.98
#
#       SD in $\mathrm{\frac{EUR}{m^2}}$  Historical data points  ...
# 2002                              0.74                       8  ...
# 2003                              0.77                      11  ...
# 2004                              0.95                      15  ...
# 2005                              0.74                      15  ...
# 2006                              0.67                      17  ...
# 2007                              0.79                      18  ...
# 2008                              1.00                     135  ...
# 2009                              1.29                     410  ...
# 2010                              1.28                    2254  ...
# 2011                              1.25                    2382  ...
# 2012                              1.29                    2392  ...
# 2013                              1.34                    2406  ...
# 2014                              1.33                    2399  ...
# 2015                              1.31                    2458  ...
# 2016                              1.38                    2449  ...
# 2017                              1.53                    2471  ...
#
# [16 rows x 2473 columns]

# %%
tex_table=df_copy[["aach", "aachen", "...", "Mean in $\\mathrm{\\frac{EUR}{m^2}}$", "SD in $\\mathrm{\\frac{EUR}{m^2}}$", "Historical data points"]]

# %%
tex_table
# Out:
#       aach  aachen  ...  Mean in $\mathrm{\frac{EUR}{m^2}}$  \
# 2002   NaN     NaN  ...                                5.48
# 2003   NaN     NaN  ...                                5.27
# 2004   NaN     NaN  ...                                5.66
# 2005   NaN     NaN  ...                                5.27
# 2006   NaN     NaN  ...                                5.22
# 2007   NaN     NaN  ...                                4.93
# 2008   NaN     NaN  ...                                4.91
# 2009  6.68     NaN  ...                                5.55
# 2010  5.14    6.95  ...                                5.27
# 2011  5.68    7.19  ...                                5.30
# 2012  5.97    7.63  ...                                5.29
# 2013  5.09    7.92  ...                                5.31
# 2014  6.53    8.16  ...                                5.36
# 2015  6.37    8.30  ...                                5.47
# 2016  6.69    8.64  ...                                5.73
# 2017  7.04    8.87  ...                                5.98
#
#       SD in $\mathrm{\frac{EUR}{m^2}}$  Historical data points
# 2002                              0.74                       8
# 2003                              0.77                      11
# 2004                              0.95                      15
# 2005                              0.74                      15
# 2006                              0.67                      17
# 2007                              0.79                      18
# 2008                              1.00                     135
# 2009                              1.29                     410
# 2010                              1.28                    2254
# 2011                              1.25                    2382
# 2012                              1.29                    2392
# 2013                              1.34                    2406
# 2014                              1.33                    2399
# 2015                              1.31                    2458
# 2016                              1.38                    2449
# 2017                              1.53                    2471

# %%
with open('..\\paper\\Table_raw.tex','w') as tf:
    tf.write(tex_table.to_latex(escape=False))

# %% [markdown]
# __Keep raw dataframe for later use, without any calculations in it__

# %%
df_raw=rename(df_raw)

# %%
df_raw
# Out:
#                2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# aach            NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.68  5.14  5.68
# aachen          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.95  7.19
# aalen           NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.90  6.10  6.15
# aarbergen       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.20  5.46
# abensberg       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.53  6.05
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# zusmarshausen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.55  5.72
# zweibruecken    NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.58  4.88  4.93
# zwenkau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.02  4.97
# zwickau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.80  4.84
# zwingenberg     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  7.62  7.50
#
#                2012  2013  2014  2015  2016  2017
# aach           5.97  5.09  6.53  6.37  6.69  7.04
# aachen         7.63  7.92  8.16  8.30  8.64  8.87
# aalen          6.39  6.73  7.12  7.62  8.38  8.66
# aarbergen      5.17  4.97  5.13  5.17  5.60  5.71
# abensberg      5.81  5.96  5.93  6.87  8.01  7.90
# ...             ...   ...   ...   ...   ...   ...
# zusmarshausen  6.00  6.33  6.17  6.08  7.51  7.68
# zweibruecken   5.10  5.07  5.14  5.27  5.39  5.71
# zwenkau        5.03  5.19  5.40  5.35  5.59  6.29
# zwickau        4.93  4.99  5.09  5.10  5.23  5.43
# zwingenberg    7.26  7.92  8.01  7.92  7.77  8.66
#
# [2469 rows x 16 columns]

# %% [markdown]
# __Part 2 - Creating dictionary of states-cities__

# %% [markdown]
# __List all manually downloaded .txt files in subdirectory__

# %%
states=os.listdir("data\\cities_by_state")

# %% [markdown]
# __Now we want to achieve a dictionary that maps for a given city the corresponding state it is matching to__

# %%
def create_states_cities_dict():
    dict={}
    for state in states:
        #open each .txt file and state read contents
        with open("data\\cities_by_state\\"+state+"\cities.txt","r", encoding="utf-8") as file:
            text=file.read()
            #regex for finding all names of cities after a "\n", the difficulty is to find different styles of writing
            # for instance Halle (Saale) or  Bad Waldsee. I figured thetr is a maximum of 3 repetitions of "words" and 
            # whitespaces and after each city name there are numbers that shouldn't get matched
            cities=re.findall("\n(\S+\s*\S*\s*\S*\s*\S*)(?=\d{1,2}\,)", text)
            #filter remaining digits, this is necessary because when there are coming 2 digits after a city name one
            #of that is matched
            cities=[re.sub("\d","",element) for element in cities]
            #convert all letters to lowercase and remove whitespaces and german umlauts to achieve a better consistency
            cities=[x.lower() for x in cities]
            cities=[re.sub(" ","",string) for string in cities]
            cities=[re.sub("Ü|ü","ue",string) for string in cities]
            cities=[re.sub("Ä|ä","ae",string) for string in cities]
            cities=[re.sub("Ö|ö","oe",string) for string in cities]
            cities=[re.sub("ß","ss",string) for string in cities]
            dict[state]=cities
    return dict

# %% [markdown]
# __Get dictionary and save it__

# %%
dict_state_to_city=create_states_cities_dict()

# %%
dict_state_to_city
# Out:
# {'Baden-Wuerttemberg': ['aalen',
#   'abstatt',
#   'achberg',
#   'achstetten',
#   'adelberg',
#   'adelmannsfelden',
#   'adelsheim',
#   'affalterbach',
#   'aglasterhausen',
#   'aichelberg',
#   'aichhalden',
#   'aichstetten',
#   'aichtal',
#   'aichwald',
#   'aidlingen',
#   'aitern',
#   'aitrach',
#   'albbruck',
#   'albershausen',
#   'albstadt',
#   'aldingen',
#   'alfdorf',
#   'allensbach',
#   'alleshausen',
#   'allmannsweiler',
#   'alpirsbach',
#   'altbach',
#   'altensteig',
#   'altheim',
#   'althengstett',
#   'althuette',
#   'altlussheim',
#   'altshausen',
#   'ammerbuch',
#   'amstetten',
#   'amtzell',
#   'angelbachtal',
#   'appenweier',
#   'argenbuehl',
#   'asbach',
#   'aspach',
#   'asperg',
#   'assamstadt',
#   'asselfingen',
#   'attenweiler',
#   'auenwald',
#   'auggen',
#   'aulendorf',
#   'backnang',
#   'badbellingen',
#   'badditzenbach',
#   'badduerrheim',
#   'badfriedrichshall',
#   'badherrenalb',
#   'badkrozingen',
#   'badliebenzell',
#   'badmergentheim',
#   'badpeterstal-griesbach',
#   'badrappenau',
#   'badrippoldsau-schapbach',
#   'badschussenried',
#   'badschoenborn',
#   'badsaeckingen',
#   'badteinach-zavelstein',
#   'badurach',
#   'badwaldsee',
#   'badwildbad',
#   'badwimpfen',
#   'badwurzach',
#   'badueberkingen',
#   'baden-baden',
#   'badenweiler',
#   'baienfurt',
#   'baiersbronn',
#   'balgheim',
#   'balingen',
#   'ballendorf',
#   'ballrechten-dottingen',
#   'baltmannsweiler',
#   'balzheim',
#   'bammental',
#   'bartholomae',
#   'beilstein',
#   'beimerstetten',
#   'bempflingen',
#   'bergatreute',
#   'berghaupten',
#   'berghuelen',
#   'berkheim',
#   'bermatingen',
#   'beuron',
#   'biberach',
#   'biberachanderriss',
#   'bietigheim',
#   'bietigheim-bissingen',
#   'billigheim',
#   'binau',
#   'binzen',
#   'birenbach',
#   'bischweier',
#   'bisingen',
#   'bissingen',
#   'bitz',
#   'blaubeuren',
#   'blaufelden',
#   'blaustein',
#   'blumberg',
#   'bodelshausen',
#   'bodman-ludwigshafen',
#   'bodnegg',
#   'bollschweil',
#   'bondorf',
#   'bopfingen',
#   'brackenheim',
#   'braunsbach',
#   'breitingen',
#   'breitnau',
#   'bretten',
#   'bretzfeld',
#   'brigachtal',
#   'bubsheim',
#   'buchen',
#   'buchheim',
#   'buggingen',
#   'burgrieden',
#   'burgstetten',
#   'burladingen',
#   'baerenbach',
#   'baerenthal',
#   'boeblingen',
#   'boehmenkirch',
#   'boertlingen',
#   'boesingen',
#   'boettingen',
#   'boetzingen',
#   'buehl',
#   'buehlertann',
#   'calw',
#   'cleebronn',
#   'crailsheim',
#   'creglingen',
#   'daisendorf',
#   'dauchingen',
#   'dautmergen',
#   'deckenpfronn',
#   'deggenhausertal',
#   'deggingen',
#   'deilingen',
#   'deizisau',
#   'deisslingen',
#   'denkendorf',
#   'denkingen',
#   'denzlingen',
#   'dettenhausen',
#   'dettenheim',
#   'dettighofen',
#   'dielheim',
#   'dietenheim',
#   'dietingen',
#   'dischingen',
#   'ditzingen',
#   'dobel',
#   'dogern',
#   'donzdorf',
#   'dormettingen',
#   'dornhan',
#   'dornstadt',
#   'dornstetten',
#   'dossenheim',
#   'dotternhausen',
#   'drackenstein',
#   'dunningen',
#   'durbach',
#   'durchhausen',
#   'durlangen',
#   'durmersheim',
#   'dusslingen',
#   'doerzbach',
#   'duerbheim',
#   'duermentingen',
#   'duernau',
#   'ebenweiler',
#   'eberdingen',
#   'eberhardzell',
#   'ebersbach',
#   'ebersbach-musbach',
#   'eberstadt',
#   'ebhausen',
#   'ebringen',
#   'egenhausen',
#   'egesheim',
#   'eggenstein-leopoldshafen',
#   'eggingen',
#   'ehingen',
#   'ehningen',
#   'ehrenkirchen',
#   'eigeltingen',
#   'eimeldingen',
#   'eislingen/fils',
#   'elchesheim-illingen',
#   'ellenberg',
#   'ellwangen(jagst)',
#   'elztal',
#   'emerkingen',
#   'emmendingen',
#   'emmingen-liptingen',
#   'empfingen',
#   'engelsbrand',
#   'engen',
#   'engstingen',
#   'enzkloesterle',
#   'epfenbach',
#   'epfendorf',
#   'eppelheim',
#   'eppingen',
#   'eriskirch',
#   'erkenbrechtsweiler',
#   'erlenmoos',
#   'erligheim',
#   'erolzheim',
#   'ertingen',
#   'eschbach',
#   'eschbronn',
#   'eschelbronn',
#   'essingen',
#   'esslingen',
#   'esslingenamneckar',
#   'ettenheim',
#   'ettlingen',
#   'fahrenbach',
#   'fellbach',
#   'fichtenberg',
#   'filderstadt',
#   'fischerbach',
#   'fischingen',
#   'flein',
#   'fleischwangen',
#   'fluorn-winzeln',
#   'forbach',
#   'frankenhardt',
#   'freiamt',
#   'freiburg',
#   'freiburgimbreisgau',
#   'freudenstadt',
#   'freudental',
#   'frickingen',
#   'friedenweiler',
#   'friedrichshafen',
#   'friesenheim',
#   'friolzheim',
#   'frittlingen',
#   'fronreute',
#   'gaggenau',
#   'gaiberg',
#   'gaienhofen',
#   'gaildorf',
#   'gammelshausen',
#   'gammertingen',
#   'gechingen',
#   'geisingen',
#   'geislingen',
#   'geislingenandersteige',
#   'gemmingen',
#   'gemmrigheim',
#   'gengenbach',
#   'gerabronn',
#   'gerlingen',
#   'gernsbach',
#   'gerstetten',
#   'glatten',
#   'glottertal',
#   'gomadingen',
#   'gomaringen',
#   'gondelsheim',
#   'gosheim',
#   'gottenheim',
#   'gottmadingen',
#   'graben-neudorf',
#   'grabenstetten',
#   'grafenberg',
#   'grafenhausen',
#   'grenzach-wyhlen',
#   'griesingen',
#   'grosselfingen',
#   'grossbottwar',
#   'grosserlach',
#   'grossrinderfeld',
#   'gruibingen',
#   'grundsheim',
#   'groembach',
#   'gruenkraut',
#   'gruensfeld',
#   'gschwend',
#   'gundelsheim',
#   'gunningen',
#   'gutenzell-huerbel',
#   'gutsbezirkmuensingen',
#   'gaertringen',
#   'gaeufelden',
#   'goeggingen',
#   'goeppingen',
#   'goerwihl',
#   'gueglingen',
#   'guetenbach',
#   'haigerloch',
#   'haiterbach',
#   'hambruecken',
#   'hardheim',
#   'hardt',
#   'hartheim',
#   'hasel',
#   'hattenhofen',
#   'hausach',
#   'hayingen',
#   'hassmersheim',
#   'heddesheim',
#   'heidelberg',
#   'heidenheim',
#   'heidenheimanderbrenz',
#   'heilbronn',
#   'heiligenberg',
#   'heiligkreuzsteinach',
#   'heimsheim',
#   'heiningen',
#   'helmstadt-bargen',
#   'hemmingen',
#   'hemsbach',
#   'herbertingen',
#   'herbolzheim',
#   'herdwangen-schoenach',
#   'hermaringen',
#   'heroldstatt',
#   'herrenberg',
#   'herrischried',
#   'hessigheim',
#   'hettingen',
#   'heubach',
#   'heuchlingen',
#   'hildrizhausen',
#   'hilzingen',
#   'hinterzarten',
#   'hirrlingen',
#   'hirschberg',
#   'hochdorf',
#   'hockenheim',
#   'hofstetten',
#   'hohberg',
#   'hohentengen',
#   'holzmaden',
#   'horbamneckar',
#   'horben',
#   'horgenzell',
#   'horn',
#   'hornberg',
#   'hosskirch',
#   'haeg-ehrsberg',
#   'haeusern',
#   'hoechenschwand',
#   'hoepfingen',
#   'hueffenhardt',
#   'huegelsheim',
#   'huelben',
#   'huettisheim',
#   'iffezheim',
#   'iggingen',
#   'ihringen',
#   'illerkirchberg',
#   'illerrieden',
#   'illmensee',
#   'ilsfeld',
#   'ilvesheim',
#   'immendingen',
#   'ingelfingen',
#   'ingersheim',
#   'ingoldingen',
#   'inzigkofen',
#   'inzlingen',
#   'irndorf',
#   'ispringen',
#   'ittlingen',
#   'jestetten',
#   'jungingen',
#   'kandern',
#   'kappelrodeck',
#   'karlsbad',
#   'karlsdorf-neuthard',
#   'karlsruhe',
#   'keltern',
#   'kenzingen',
#   'ketsch',
#   'kieselbronn',
#   'kirchardt',
#   'kirchdorf',
#   'kirchheimunterteck',
#   'kirchzarten',
#   'kisslegg',
#   'klettgau',
#   'knittlingen',
#   'kohlberg',
#   'kolbingen',
#   'konstanz',
#   'korb',
#   'korntal-muenchingen',
#   'kornwestheim',
#   'kraichtal',
#   'krauchenwies',
#   'krautheim',
#   'kronau',
#   'kuchen',
#   'kupferzell',
#   'kuppenheim',
#   'kusterdingen',
#   'kaempfelbach',
#   'koengen',
#   'koenigheim',
#   'koenigsbach-stein',
#   'koenigsbronn',
#   'koenigsfeld',
#   'koenigsheim',
#   'kuelsheim',
#   'kuenzelsau',
#   'kuernbach',
#   'kuessaberg',
#   'ladenburg',
#   'lahr',
#   'lahr/schwarzwald',
#   'laichingen',
#   'langenargen',
#   'langenau',
#   'langenbrettach',
#   'langenburg',
#   'langenenslingen',
#   'lauchheim',
#   'lauchringen',
#   'lauda-koenigshofen',
#   'lautenbach',
#   'lauterstein',
#   'lehrensteinsfeld',
#   'leimen',
#   'leinfelden-echterdingen',
#   'leingarten',
#   'lenningen',
#   'lenzkirch',
#   'leonberg',
#   'leutenbach',
#   'leutkirchimallgaeu',
#   'lichtenwald',
#   'linkenheim-hochstetten',
#   'lobbach',
#   'loffenau',
#   'lonsee',
#   'lottstetten',
#   'lossburg',
#   'ludwigsburg',
#   'loechgau',
#   'loeffingen',
#   'loerrach',
#   'magstadt',
#   'mahlstetten',
#   'mainhardt',
#   'malsburg-marzell',
#   'malsch',
#   'mannheim',
#   'march',
#   'markdorf',
#   'maselheim',
#   'massenbachhausen',
#   'mauer',
#   'maulbronn',
#   'maulburg',
#   'meckenbeuren',
#   'meckesheim',
#   'mehrstetten',
#   'meissenheim',
#   'merdingen',
#   'merklingen',
#   'merzhausen',
#   'metzingen',
#   'messkirch',
#   'messstetten',
#   'michelbachanderbilz',
#   'mietingen',
#   'moos',
#   'mosbach',
#   'mudau',
#   'mulfingen',
#   'murg',
#   'mutlangen',
#   'moeckmuehl',
#   'moegglingen',
#   'moeglingen',
#   'moenchweiler',
#   'moensheim',
#   'moessingen',
#   'moetzingen',
#   'muehlacker',
#   'muehlenbach',
#   'muehlhausen-ehingen',
#   'muehlingen',
#   'nagold',
#   'nattheim',
#   'neckarbischofsheim',
#   'neckargemuend',
#   'neckargerach',
#   'neckarsulm',
#   'neckartailfingen',
#   'neckartenzlingen',
#   'neckarwestheim',
#   'neckarzimmern',
#   'neenstetten',
#   'nehren',
#   'neidenstein',
#   'neidlingen',
#   'nellingen',
#   'neubulach',
#   'neudenau',
#   'neuenbuerg',
#   'neuffen',
#   'neuhausen',
#   'neuler',
#   'neulingen',
#   'neustetten',
#   'neuweiler',
#   'niedereschach',
#   'niedernhall',
#   'niederstetten',
#   'niederstotzingen',
#   'niefern-oeschelbronn',
#   'nordrach',
#   'notzingen',
#   'nufringen',
#   'nusplingen',
#   'nussloch',
#   'nuertingen',
#   'oberboihingen',
#   'oberderdingen',
#   'oberdischingen',
#   'oberharmersbach',
#   'oberhausen-rheinhausen',
#   'oberkochen',
#   'obernheim',
#   'oberried',
#   'oberriexingen',
#   'oberrot',
#   'obersontheim',
#   'obersulm',
#   'oberteuringen',
#   'oberwolfach',
#   'ochsenhausen',
#   'oedheim',
#   'offenau',
#   'offenburg',
#   'ofterdingen',
#   'oftersheim',
#   'ohlsbach',
#   'ohmden',
#   'oppenau',
#   'orsingen-nenzingen',
#   'ostelsheim',
#   'osterburken',
#   'ostfildern',
#   'ostrach',
#   'ottenhoefen',
#   'owen',
#   'owingen',
#   'pfaffenweiler',
#   'pfalzgrafenweiler',
#   'pfedelbach',
#   'pfinztal',
#   'pforzheim',
#   'pfronstetten',
#   'pfullendorf',
#   'philippsburg',
#   'plankstadt',
#   'pliezhausen',
#   'plochingen',
#   'radolfzellambodensee',
#   'rainau',
#   'rammingen',
#   'rangendingen',
#   'rastatt',
#   'ratshausen',
#   'rauenberg',
#   'ravensburg',
#   'ravenstein',
#   'rechberghausen',
#   'reichartshausen',
#   'reilingen',
#   'remchingen',
#   'remseckamneckar',
#   'remshalden',
#   'renquishausen',
#   'reute',
#   'reutlingen',
#   'rheinau',
#   'rheinfelden(baden)',
#   'rheinhausen',
#   'rheinstetten',
#   'rickenbach',
#   'riederich',
#   'riedhausen',
#   'rielasingen-worblingen',
#   'rietheim-weilheim',
#   'roigheim',
#   'rosenberg',
#   'rosenfeld',
#   'rottenacker',
#   'rust',
#   'roemerstein',
#   'sachsenheim',
#   'salach',
#   'salem',
#   'sandhausen',
#   'sasbachwalden',
#   'satteldorf',
#   'schallbach',
#   'schallstadt',
#   'schechingen',
#   'scheer',
#   'schefflenz',
#   'schemmerhofen',
#   'schenkenzell',
#   'schiltach',
#   'schlaitdorf',
#   'schlat',
#   'schliengen',
#   'schlier',
#   'schluchsee',
#   'schnuerpflingen',
#   'schopfheim',
#   'schorndorf',
#   'schramberg',
#   'schriesheim',
#   'schrozberg',
#   'schuttertal',
#   'schutterwald',
#   'schwaigern',
#   'schwaikheim',
#   'schwanau',
#   'schwarzach',
#   'schwendi',
#   'schwieberdingen',
#   'schwaebischgmuend',
#   'schwaebischhall',
#   'schwoerstadt',
#   'schoemberg',
#   'schoenaich',
#   'schoenbrunn',
#   'schoental',
#   'seckach',
#   'seelbach',
#   'seitingen-oberflacht',
#   'sersheim',
#   'sexau',
#   'siegelsbach',
#   'sigmaringen',
#   'simmersfeld',
#   'simonswald',
#   'sindelfingen',
#   'singen(hohentwiel)',
#   'sinsheim',
#   'sipplingen',
#   'sonnenbuehl',
#   'spaichingen',
#   'spechbach',
#   'spiegelberg',
#   'st.leon-rot',
#   'st.maergen',
#   'st.peter',
#   'starzach',
#   'stegen',
#   'steinach',
#   'steinen',
#   'steinmauern',
#   'steisslingen',
#   'sternenfels',
#   'straubenhardt',
#   'strassberg',
#   'stutensee',
#   'stuttgart',
#   'stoedtlen',
#   'stuehlingen',
#   'sulzbach-laufen',
#   'sulzburg',
#   'sulzfeld',
#   'soelden',
#   'talheim',
#   'tauberbischofsheim',
#   'tengen',
#   'teningen',
#   'tettnang',
#   'tiefenbronn',
#   'titisee-neustadt',
#   'todtmoos',
#   'todtnau',
#   'trochtelfingen',
#   'trossingen',
#   'tuningen',
#   'tuttlingen',
#   'tuebingen',
#   'ubstadt-weiher',
#   'uhingen',
#   'uhldingen-muehlhofen',
#   'ulm',
#   'umkirch',
#   'ummendorf',
#   'untereisesheim',
#   'unterensingen',
#   'untergruppenbach',
#   'untermarchtal',
#   'untermuenkheim',
#   'unterstadion',
#   'urbach',
#   'uttenweiler',
#   'utzenfeld',
#   'vaihingenanderenz',
#   'vellberg',
#   'veringenstadt',
#   'villingen-schwenningen',
#   'vogt',
#   'volkertshausen',
#   'voehrenbach',
#   'voerstetten',
#   'waghaeusel',
#   'waiblingen',
#   'waibstadt',
#   'wain',
#   'waldachtal',
#   'waldbronn',
#   'waldburg',
#   'waldkirch',
#   'waldshut-tiengen',
#   'walheim',
#   'walldorf',
#   'wallhausen',
#   'walzbachtal',
#   'wangen',
#   'wangenimallgaeu',
#   'wannweil',
#   'warthausen',
#   'wehr',
#   'weilamrhein',
#   'weilderstadt',
#   'weingarten',
#   'weinheim',
#   'weinsberg',
#   'weinstadt',
#   'weisenbach',
#   'weissach',
#   'weisweil',
#   'weissbach',
#   'wellendingen',
#   'werbach',
#   'wertheim',
#   'westerstetten',
#   'westhausen',
#   'widdern',
#   'wieden',
#   'wiernsheim',
#   'wiesenbach',
#   'wiesloch',
#   'wildberg',
#   'wilhelmsdorf',
#   'wilhelmsfeld',
#   'wimsheim',
#   'winden',
#   'winnenden',
#   'winterbach',
#   'winterlingen',
#   'wittnau',
#   'wolfegg',
#   'wolfschlugen',
#   'wolpertshausen',
#   'wolpertswende',
#   'wurmlingen',
#   'wutach',
#   'wutoeschingen',
#   'woernersberg',
#   'woert',
#   'zaberfeld',
#   'zell',
#   'zimmern',
#   'zuzenhausen',
#   'zwiefalten',
#   'oehningen',
#   'oehringen',
#   'oelbronn-duerrn',
#   'oepfingen',
#   'oestringen',
#   'oetigheim',
#   'oetisheim',
#   'uehlingen-birkendorf'],
#  'Bayern': ['abenberg',
#   'abensberg',
#   'absberg',
#   'abtswind',
#   'achslach',
#   'adelschlag',
#   'adelsdorf',
#   'adelshofen',
#   'adelsried',
#   'adelzhausen',
#   'adlkofen',
#   'affing',
#   'aham',
#   'aholfing',
#   'aholming',
#   'ahorn',
#   'ahorntal',
#   'aichach',
#   'aichen',
#   'aidenbach',
#   'aidhausen',
#   'aiglsbach',
#   'aindling',
#   'ainring',
#   'aislingen',
#   'aiterhofen',
#   'albaching',
#   'albertshofen',
#   'alerheim',
#   'alesheim',
#   'aletshausen',
#   'alfeld',
#   'allersberg',
#   'allershausen',
#   'alling',
#   'allmannshofen',
#   'altdorf',
#   'alteglofsheim',
#   'altenbuch',
#   'altendorf',
#   'altenkunstadt',
#   'altenmuenster',
#   'altenstadt',
#   'altertheim',
#   'altfraunhofen',
#   'althegnenberg',
#   'altmannstein',
#   'altomuenster',
#   'altusried',
#   'altoetting',
#   'alzenau',
#   'amberg',
#   'amerang',
#   'amerdingen',
#   'ammerndorf',
#   'ammerthal',
#   'ampfing',
#   'andechs',
#   'anger',
#   'ansbach',
#   'antdorf',
#   'anzing',
#   'apfeldorf',
#   'apfeltrach',
#   'arberg',
#   'aresing',
#   'arnbruck',
#   'arnschwang',
#   'arnstein',
#   'arnstorf',
#   'arrach',
#   'arzberg',
#   'asbach-baeumenheim',
#   'ascha',
#   'aschaffenburg',
#   'aschheim',
#   'attenhofen',
#   'attenkirchen',
#   'atting',
#   'au',
#   'aub',
#   'aubstadt',
#   'auerbach',
#   'aufhausen',
#   'aufsess',
#   'augsburg',
#   'auhausen',
#   'aurach',
#   'aurachtal',
#   'aussernzell',
#   'aying',
#   'aystetten',
#   'assling',
#   'baar',
#   'baar-ebenhausen',
#   'babenhausen',
#   'babensham',
#   'bachhagel',
#   'badabbach',
#   'badaibling',
#   'badalexandersbad',
#   'badbayersoien',
#   'badbirnbach',
#   'badbocklet',
#   'badendorf',
#   'badfeilnbach',
#   'badfuessing',
#   'badgroenenbach',
#   'badheilbrunn',
#   'badkissingen',
#   'badkohlgrub',
#   'badreichenhall',
#   'badrodach',
#   'badstaffelstein',
#   'badsteben',
#   'badtoelz',
#   'badwiessee',
#   'badwindsheim',
#   'badwoerishofen',
#   'baierbach',
#   'baierbrunn',
#   'baiern',
#   'baiersdorf',
#   'baisweil',
#   'balderschwang',
#   'balzhausen',
#   'bamberg',
#   'barbing',
#   'bastheim',
#   'baudenbach',
#   'baunach',
#   'bayerbach',
#   'bayerischeisenstein',
#   'bayerischgmain',
#   'bayreuth',
#   'bayrischzell',
#   'bechhofen',
#   'bechtsrieth',
#   'beilngries',
#   'bellenberg',
#   'benediktbeuern',
#   'beratzhausen',
#   'berching',
#   'berg',
#   'bergimgau',
#   'bergen',
#   'bergkirchen',
#   'berglern',
#   'bergrheinfeld',
#   'bergtheim',
#   'bernau',
#   'bernbeuren',
#   'berngau',
#   'bernried',
#   'bessenbach',
#   'betzenstein',
#   'betzigau',
#   'biberbach',
#   'bibertal',
#   'biburg',
#   'bichl',
#   'bidingen',
#   'biebelried',
#   'bieberehren',
#   'biessenhofen',
#   'bindlach',
#   'binswangen',
#   'birgland',
#   'birkenfeld',
#   'birnbach',
#   'bischberg',
#   'bischofsmais',
#   'bischofswiesen',
#   'blaibach',
#   'blaichach',
#   'blankenbach',
#   'blindheim',
#   'bobingen',
#   'bodenkirchen',
#   'bodenmais',
#   'bodenwoehr',
#   'bodolz',
#   'bogen',
#   'bolsterlang',
#   'bonstetten',
#   'boos',
#   'brand',
#   'brannenburg',
#   'breitbrunn',
#   'breitenguessbach',
#   'breitenthal',
#   'brennberg',
#   'bruck',
#   'bruckberg',
#   'bruckmuehl',
#   'brunn',
#   'brunnen',
#   'brunnthal',
#   'bubenreuth',
#   'bubesheim',
#   'buch',
#   'bucha.wald',
#   'buchdorf',
#   'buchenberg',
#   'buchhofen',
#   'buchloe',
#   'buckenhof',
#   'bundorf',
#   'burgau',
#   'burggen',
#   'burghaslach',
#   'burghausen',
#   'burgheim',
#   'burgkunstadt',
#   'burglauer',
#   'burglengenfeld',
#   'burgoberbach',
#   'burgpreppach',
#   'burgsinn',
#   'burgthann',
#   'burgwindheim',
#   'burk',
#   'burtenbach',
#   'buttenheim',
#   'buttenwiesen',
#   'buxheim',
#   'baernau',
#   'boebing',
#   'boebrach',
#   'boehen',
#   'boehmfeld',
#   'buechenbach',
#   'buechlberg',
#   'buetthard',
#   'cadolzburg',
#   'cham',
#   'chamerau',
#   'chieming',
#   'coburg',
#   'collenberg',
#   'colmberg',
#   'creussen',
#   'dachau',
#   'dachsbach',
#   'daiting',
#   'dammbach',
#   'dasing',
#   'deggendorf',
#   'deining',
#   'deiningen',
#   'deisenhausen',
#   'denklingen',
#   'dettelbach',
#   'deuerling',
#   'diebach',
#   'diedorf',
#   'diespeck',
#   'dietenhofen',
#   'dietersburg',
#   'dietersheim',
#   'dieterskirchen',
#   'dietmannsried',
#   'dietramszell',
#   'dingolfing',
#   'dingolshausen',
#   'dinkelsbuehl',
#   'dinkelscherben',
#   'dittelbrunn',
#   'dittenheim',
#   'dollnstein',
#   'dombuehl',
#   'donaustauf',
#   'donauwoerth',
#   'donnersdorf',
#   'dorfprozelten',
#   'dormitz',
#   'drachselsried',
#   'duggendorf',
#   'durach',
#   'doehlau',
#   'doerfles-esbach',
#   'duerrlauingen',
#   'duerrwangen',
#   'ebelsbach',
#   'ebensfeld',
#   'eberfing',
#   'ebermannsdorf',
#   'ebermannstadt',
#   'ebern',
#   'ebersberg',
#   'ebersdorf',
#   'ebnath',
#   'ebrach',
#   'eching',
#   'eckental',
#   'ederheim',
#   'edling',
#   'effeltrich',
#   'egenhofen',
#   'eggenfelden',
#   'eggenthal',
#   'egglham',
#   'egglkofen',
#   'eggolsheim',
#   'eggstaett',
#   'eglfing',
#   'egling',
#   'egloffstein',
#   'egmating',
#   'egweil',
#   'ehekirchen',
#   'eibelstadt',
#   'eichenau',
#   'eichenbuehl',
#   'eichendorf',
#   'eichstaett',
#   'eiselfing',
#   'eisenheim',
#   'eisingen',
#   'eitensheim',
#   'eitting',
#   'elchingen',
#   'elfershausen',
#   'ellgau',
#   'ellingen',
#   'ellzee',
#   'elsendorf',
#   'elsenfeld',
#   'eltmann',
#   'emersacker',
#   'emmering',
#   'emmerting',
#   'emskirchen',
#   'emtmannsberg',
#   'engelsberg',
#   'engelthal',
#   'eppenschlag',
#   'eppishausen',
#   'erbendorf',
#   'erding',
#   'erdweg',
#   'eresing',
#   'ergersheim',
#   'ergolding',
#   'ergoldsbach',
#   'erharting',
#   'ering',
#   'erkheim',
#   'erlangen',
#   'erlbach',
#   'erlenbach',
#   'ermershausen',
#   'ernsgaden',
#   'eschau',
#   'eschenlohe',
#   'eschlkam',
#   'eslarn',
#   'esselbach',
#   'essenbach',
#   'essing',
#   'estenfeld',
#   'ettal',
#   'ettenstatt',
#   'ettringen',
#   'etzelwang',
#   'etzenricht',
#   'euerbach',
#   'eurasburg',
#   'eussenheim',
#   'fahrenzhausen',
#   'falkenberg',
#   'falkenfels',
#   'farchant',
#   'faulbach',
#   'feilitzsch',
#   'feldkirchen',
#   'feldkirchen-westerham',
#   'fellen',
#   'fellheim',
#   'fensterbach',
#   'feuchtwangen',
#   'fichtelberg',
#   'finning',
#   'finningen',
#   'finsing',
#   'fischach',
#   'fischbachau',
#   'flachslanden',
#   'fladungen',
#   'flossenbuerg',
#   'floss',
#   'forchheim',
#   'forstern',
#   'forstinning',
#   'frankenwinheim',
#   'frasdorf',
#   'frauenau',
#   'frauenneuharting',
#   'fraunberg',
#   'freihung',
#   'freilassing',
#   'freising',
#   'fremdingen',
#   'frensdorf',
#   'freystadt',
#   'freyung',
#   'frickenhausen',
#   'fridolfing',
#   'friedenfels',
#   'friesenried',
#   'frontenhausen',
#   'fuchsmuehl',
#   'fuchsstadt',
#   'fuchstal',
#   'furth',
#   'fuenfstetten',
#   'fuersteneck',
#   'fuerstenfeldbruck',
#   'fuerstenstein',
#   'fuerstenzell',
#   'fuerth',
#   'fuessen',
#   'gablingen',
#   'gachenbach',
#   'gaimersheim',
#   'gaissach',
#   'gallmersgarten',
#   'gammelsdorf',
#   'gangkofen',
#   'garmisch-partenkirchen',
#   'gattendorf',
#   'gaukoenigshofen',
#   'gauting',
#   'gebenbach',
#   'gebsattel',
#   'gefrees',
#   'geiersthal',
#   'geiselhoering',
#   'geiselwind',
#   'geisenfeld',
#   'geisenhausen',
#   'gelchsheim',
#   'geldersheim',
#   'geltendorf',
#   'gemuenden',
#   'genderkingen',
#   'georgenberg',
#   'georgensgmuend',
#   'gerach',
#   'geratskirchen',
#   'gerbrunn',
#   'geretsried',
#   'gerhardshofen',
#   'germaringen',
#   'germering',
#   'geroda',
#   'geroldshausen',
#   'gerolfingen',
#   'gerolsbach',
#   'gerolzhofen',
#   'gersthofen',
#   'gerzen',
#   'gesees',
#   'geslau',
#   'gessertshausen',
#   'gestratz',
#   'giebelstadt',
#   'gilching',
#   'glattbach',
#   'gleiritsch',
#   'gleissenberg',
#   'gloett',
#   'gnotzheim',
#   'gochsheim',
#   'goldbach',
#   'goldkronach',
#   'gollhofen',
#   'gotteszell',
#   'gottfrieding',
#   'graben',
#   'grabenstaett',
#   'grafenau',
#   'grafengehaig',
#   'grafenrheinfeld',
#   'grafenwiesen',
#   'grafenwoehr',
#   'grafling',
#   'grafrath',
#   'grainau',
#   'grasbrunn',
#   'grassau',
#   'grattersdorf',
#   'greding',
#   'greifenberg',
#   'greiling',
#   'gremsdorf',
#   'grettstadt',
#   'greussenheim',
#   'griesstaett',
#   'grossaitingen',
#   'grossenseebach',
#   'grosshabersdorf',
#   'grossheirath',
#   'grossheubach',
#   'grosskarolinenfeld',
#   'grossmehring',
#   'grossostheim',
#   'grosswallstadt',
#   'grossweil',
#   'grub',
#   'graefelfing',
#   'groebenzell',
#   'gruenwald',
#   'gundelfingen',
#   'gundremmingen',
#   'gunzenhausen',
#   'guteneck',
#   'gutenstetten',
#   'guttenberg',
#   'gaedheim',
#   'goerisried',
#   'goessenheim',
#   'goessweinstein',
#   'guentersleben',
#   'guenzach',
#   'guenzburg',
#   'haag',
#   'haar',
#   'haarbach',
#   'habach',
#   'hagelstadt',
#   'hahnbach',
#   'haibach',
#   'haimhausen',
#   'haiming',
#   'hainsfarth',
#   'halblech',
#   'haldenwang',
#   'halfing',
#   'hallbergmoos',
#   'hallerndorf',
#   'hallstadt',
#   'halsbach',
#   'hambach',
#   'hammelburg',
#   'happurg',
#   'harsdorf',
#   'hartenstein',
#   'haselbach',
#   'hasloch',
#   'haundorf',
#   'haunsheim',
#   'hausen',
#   'hausham',
#   'hauzenberg',
#   'hawangen',
#   'hassfurt',
#   'hebertsfelden',
#   'hebertshausen',
#   'heideck',
#   'heigenbruecken',
#   'heilsbronn',
#   'heimenkirch',
#   'heimertingen',
#   'heinersreuth',
#   'heldenstein',
#   'helmbrechts',
#   'helmstadt',
#   'hemau',
#   'hemhofen',
#   'hendungen',
#   'henfenfeld',
#   'hengersberg',
#   'hepberg',
#   'heretsried',
#   'hergatz',
#   'hergensweiler',
#   'heroldsbach',
#   'herrieden',
#   'herrngiersdorf',
#   'hersbruck',
#   'herzogenaurach',
#   'hettstadt',
#   'heustreu',
#   'hessdorf',
#   'hilgertshausen-tandern',
#   'hilpoltstein',
#   'hiltenfingen',
#   'hiltpoltstein',
#   'himmelkron',
#   'himmelstadt',
#   'hirschaid',
#   'hirschau',
#   'hirschbach',
#   'hitzhofen',
#   'hof',
#   'hofer',
#   'hofkirchen',
#   'hohenaltheim',
#   'hohenau',
#   'hohenbrunn',
#   'hohenburg',
#   'hohenfels',
#   'hohenfurch',
#   'hohenkammer',
#   'hohenlinden',
#   'hohenpeissenberg',
#   'hohenpolding',
#   'hohenstadt',
#   'hohenthann',
#   'hohenwart',
#   'hohenwarth',
#   'hollenbach',
#   'hollfeld',
#   'holzguenz',
#   'holzheim',
#   'holzkirchen',
#   'hopferau',
#   'huglfing',
#   'huisheim',
#   'hunderdorf',
#   'hunding',
#   'hurlach',
#   'hutthurm',
#   'hoechberg',
#   'hoehenkirchen-siegertsbrunn',
#   'hoergertshausen',
#   'hoesbach',
#   'hoeslwang',
#   'hoettingen',
#   'ichenhausen',
#   'icking',
#   'iffeldorf',
#   'iggensbach',
#   'igling',
#   'ihrlerstein',
#   'illertissen',
#   'illesheim',
#   'illschwang',
#   'ilmmuenster',
#   'inchenhofen',
#   'ingenried',
#   'ingolstadt',
#   'innernzell',
#   'insingen',
#   'inzell',
#   'iphofen',
#   'ippesheim',
#   'ipsheim',
#   'irlbach',
#   'irschenberg',
#   'irsee',
#   'isen',
#   'ismaning',
#   'issigau',
#   'itzgrund',
#   'jachenau',
#   'jandelsbrunn',
#   'jengen',
#   'jesenwang',
#   'jettenbach',
#   'jettingen',
#   'jettingen-scheppach',
#   'jetzendorf',
#   'johannesberg',
#   'johanniskirchen',
#   'julbach',
#   'kaisheim',
#   'kallmuenz',
#   'kaltental',
#   'kammeltal',
#   'kammerstein',
#   'kammlach',
#   'karbach',
#   'karlsfeld',
#   'karlshuld',
#   'karlskron',
#   'karlstadt',
#   'karsbach',
#   'kasendorf',
#   'kastl',
#   'kaufbeuren',
#   'kaufering',
#   'kemmern',
#   'kemnath',
#   'kempten',
#   'kempten(allgaeu)',
#   'kettershausen',
#   'kiefersfelden',
#   'kienberg',
#   'kinsau',
#   'kipfenberg',
#   'kirchanschoering',
#   'kirchbergi.wald',
#   'kirchehrenbach',
#   'kirchenlamitz',
#   'kirchenpingarten',
#   'kirchensittenbach',
#   'kirchham',
#   'kirchhaslach',
#   'kirchheim',
#   'kirchlauter',
#   'kirchroth',
#   'kirchseeon',
#   'kirchweidach',
#   'kirchzell',
#   'kissing',
#   'kitzingen',
#   'kleinaitingen',
#   'kleinheubach',
#   'kleinkahl',
#   'kleinostheim',
#   'kleinrinderfeld',
#   'kleinwallstadt',
#   'knetzgau',
#   'kolbermoor',
#   'kollnburg',
#   'konnersreuth',
#   'konradsreuth',
#   'kottgeisering',
#   'kraftisried',
#   'krailling',
#   'kranzberg',
#   'kreuth',
#   'kreuzwertheim',
#   'krombach',
#   'kronach',
#   'kronburg',
#   'krummennaab',
#   'kroening',
#   'kruen',
#   'kulmbach',
#   'kumhausen',
#   'kunreuth',
#   'kupferberg',
#   'kutzenhausen',
#   'koeditz',
#   'koednitz',
#   'koefering',
#   'koenigsbrunn',
#   'koenigsdorf',
#   'koenigsmoos',
#   'koesching',
#   'koetz',
#   'koesslarn',
#   'kuehbach',
#   'kuehlenthal',
#   'kuemmersbruck',
#   'kuenzing',
#   'kueps',
#   'kuernach',
#   'laberweinting',
#   'lachen',
#   'lam',
#   'lamerdingen',
#   'landensberg',
#   'landsbergamlech',
#   'landsberied',
#   'landshut',
#   'langdorf',
#   'langenaltheim',
#   'langenbach',
#   'langenmosen',
#   'langenneufnach',
#   'langensendelbach',
#   'langenzenn',
#   'langerringen',
#   'langfurth',
#   'langquaid',
#   'lappersdorf',
#   'lauben',
#   'laudenbach',
#   'laufen',
#   'laugna',
#   'lauter',
#   'lauterhofen',
#   'lautrach',
#   'legau',
#   'lehrberg',
#   'leiblfing',
#   'leidersbach',
#   'leinach',
#   'leinburg',
#   'leipheim',
#   'lengdorf',
#   'lengenwang',
#   'lenggries',
#   'lenting',
#   'leuchtenberg',
#   'leupoldsgruen',
#   'leutershausen',
#   'lichtenberg',
#   'lichtenfels',
#   'lindau(bodensee)',
#   'lindberg',
#   'lindenberg',
#   'lisberg',
#   'litzendorf',
#   'lohberg',
#   'lohkirchen',
#   'loiching',
#   'loitzendorf',
#   'lonnerstadt',
#   'ludwigschorgast',
#   'ludwigsstadt',
#   'lug',
#   'luhe-wildenau',
#   'lupburg',
#   'lutzingen',
#   'luelsfeld',
#   'maihingen',
#   'mainaschaff',
#   'mainbernheim',
#   'mainburg',
#   'mainleus',
#   'maisach',
#   'maitenbeth',
#   'malching',
#   'malgersdorf',
#   'mallersdorf-pfaffenberg',
#   'mammendorf',
#   'mamming',
#   'manching',
#   'margetshoechheim',
#   'mariaposching',
#   'marklkofen',
#   'marktberolzheim',
#   'markteinersheim',
#   'markterlbach',
#   'marktindersdorf',
#   'marktnordheim',
#   'marktrettenbach',
#   'markttaschendorf',
#   'marktwald',
#   'marktbergel',
#   'marktbreit',
#   'marktgraitz',
#   'marktleugast',
#   'marktleuthen',
#   'marktoberdorf',
#   'marktoffingen',
#   'marktredwitz',
#   'marktrodach',
#   'marktschellenberg',
#   'marktschorgast',
#   'marktsteft',
#   'marktzeuln',
#   'marloffstein',
#   'marxheim',
#   'marzling',
#   'massing',
#   'mauern',
#   'mauerstetten',
#   'mauth',
#   'maxhuette-haidhof',
#   'massbach',
#   'medlingen',
#   'meeder',
#   'megesheim',
#   'mehring',
#   'meinheim',
#   'meitingen',
#   'memmelsdorf',
#   'memmingen',
#   'memmingerberg',
#   'mengkofen',
#   'merching',
#   'mering',
#   'merkendorf',
#   'mertingen',
#   'mespelbrunn',
#   'metten',
#   'mettenheim',
#   'michelsneukirchen',
#   'mickhausen',
#   'miltach',
#   'miltenberg',
#   'mindelheim',
#   'mindelstetten',
#   'mintraching',
#   'missen-wilhams',
#   'mistelbach',
#   'mistelgau',
#   'mitteleschenbach',
#   'mittelneufnach',
#   'mittelsinn',
#   'mittelstetten',
#   'mittenwald',
#   'mitterfels',
#   'mitterskirchen',
#   'mitterteich',
#   'mitwitz',
#   'moorenweis',
#   'moosach',
#   'moosbach',
#   'moosburg',
#   'moosinning',
#   'munningen',
#   'maehring',
#   'moedingen',
#   'moehrendorf',
#   'moembris',
#   'moemlingen',
#   'moenchberg',
#   'moenchsdeggingen',
#   'moenchsroth',
#   'moernsheim',
#   'moettingen',
#   'moetzing',
#   'muehlhausen',
#   'muenchberg',
#   'muenchen',
#   'muenchsmuenster',
#   'muenchsteinach',
#   'muennerstadt',
#   'muensing',
#   'muensterhausen',
#   'nabburg',
#   'nagel',
#   'naila',
#   'nandlstadt',
#   'nassenfels',
#   'nersingen',
#   'nesselwang',
#   'neu-ulm',
#   'neualbenreuth',
#   'neubeuern',
#   'neubiberg',
#   'neubrunn',
#   'neuburg',
#   'neuching',
#   'neudrossenfeld',
#   'neuendettelsau',
#   'neuendorf',
#   'neuenmarkt',
#   'neufraunhofen',
#   'neuhof',
#   'neuhuetten',
#   'neukirchen-balbini',
#   'neuried',
#   'neusitz',
#   'neusorg',
#   'neustadt',
#   'neusaess',
#   'neutraubling',
#   'neuoetting',
#   'niederaichbach',
#   'niederalteich',
#   'niederfuellbach',
#   'niedermurach',
#   'niedernberg',
#   'niederrieden',
#   'niederschoenenfeld',
#   'niederviehbach',
#   'niederwerrn',
#   'niederwinkling',
#   'nittenau',
#   'nittendorf',
#   'nonnenhorn',
#   'nordendorf',
#   'nordhalben',
#   'nordheim',
#   'nussdorf',
#   'noerdlingen',
#   'nuedlingen',
#   'nuernberg',
#   'oberammergau',
#   'oberasbach',
#   'oberau',
#   'oberaudorf',
#   'oberaurach',
#   'oberbergkirchen',
#   'oberdachstetten',
#   'oberding',
#   'oberdolling',
#   'oberelsbach',
#   'obergriesbach',
#   'oberguenzburg',
#   'oberhaching',
#   'oberhaid',
#   'oberhof',
#   'oberickelsheim',
#   'oberkotzau',
#   'obermichelbach',
#   'oberndorf',
#   'oberneukirchen',
#   'obernzell',
#   'obernzenn',
#   'oberostendorf',
#   'oberpframmern',
#   'oberpleichfeld',
#   'oberpoering',
#   'oberreichenbach',
#   'oberreute',
#   'oberrieden',
#   'oberroth',
#   'oberscheinfeld',
#   'oberschleissheim',
#   'oberschneiding',
#   'oberschwarzach',
#   ...],
#  'Berlin': ['berlin', 'damm'],
#  'Brandenburg': ['ahrensfelde',
#   'alttucheband',
#   'altdoebern',
#   'althuettendorf',
#   'altlandsberg',
#   'badliebenwerda',
#   'badwilsnack',
#   'beelitz',
#   'beeskow',
#   'bensdorf',
#   'berge',
#   'berkholz-meyenburg',
#   'bernaubeiberlin',
#   'bestensee',
#   'biesenthal',
#   'birkenwerder',
#   'blankenfelde-mahlow',
#   'blankensee',
#   'bliesdorf',
#   'brandenburg',
#   'briesen',
#   'brieskow-finkenheerd',
#   'cottbus',
#   'damsdorf',
#   'drachhausen',
#   'drahnsdorf',
#   'doebern',
#   'eberswalde',
#   'eichwalde',
#   'eisenhuettenstadt',
#   'elsterwerda',
#   'falkensee',
#   'forst(lausitz)',
#   'frankenhain',
#   'frankfurt(oder)',
#   'frauendorf',
#   'friesack',
#   'frohnsdorf',
#   'fuerstenwalde/spree',
#   'grosskoeris',
#   'groeden',
#   'goeritz',
#   'hennigsdorf',
#   'hohenneuendorf',
#   'hohenleipisch',
#   'klausdorf',
#   'kleinmachnow',
#   'kolkwitz',
#   'koenigswusterhausen',
#   'luckenwalde',
#   'ludwigsfelde',
#   'lychen',
#   'neuruppin',
#   'nuthe-urstromtal',
#   'oranienburg',
#   'potsdam',
#   'rathenow',
#   'ruedersdorf',
#   'schipkau',
#   'schwarzheide',
#   'schwedt/oder',
#   'schoenefeld',
#   'seddinersee',
#   'senftenberg',
#   'spremberg',
#   'strausberg',
#   'teltow',
#   'wandlitz',
#   'welzow',
#   'werder',
#   'wildau',
#   'wittenberge',
#   'woltersdorf',
#   'zeuthen'],
#  'Bremen': ['bremen', 'bremerhaven'],
#  'Hamburg': ['hamburg'],
#  'Hessen': ['aarbergen',
#   'abtsteinach',
#   'ahausen',
#   'ahnatal',
#   'alheim',
#   'allendorf',
#   'alsbach-haehnlein',
#   'alsfeld',
#   'amoeneburg',
#   'angelburg',
#   'antrifttal',
#   'asslar',
#   'badarolsen',
#   'badcamberg',
#   'bademstal',
#   'badendbach',
#   'badhersfeld',
#   'badhomburg',
#   'badkarlshafen',
#   'badkoenig',
#   'badnauheim',
#   'badorb',
#   'badsalzschlirf',
#   'badschwalbach',
#   'badsodenamtaunus',
#   'badsooden-allendorf',
#   'badvilbel',
#   'badwildungen',
#   'badzwesten',
#   'baunatal',
#   'bebra',
#   'beerfelden',
#   'bensheim',
#   'berkatal',
#   'beselich',
#   'biblis',
#   'bickenbach',
#   'biebergemuend',
#   'biebertal',
#   'biedenkopf',
#   'birkenau',
#   'birstein',
#   'bischoffen',
#   'bischofsheim',
#   'brachttal',
#   'braunfels',
#   'brechen',
#   'breidenbach',
#   'breitenbach',
#   'breitscheid',
#   'brensbach',
#   'breuberg',
#   'breuna',
#   'brombachtal',
#   'bromskirchen',
#   'bruchkoebel',
#   'burghaun',
#   'burgwald',
#   'buseck',
#   'butzbach',
#   'buedingen',
#   'buerstadt',
#   'buettelborn',
#   'calden',
#   'cornberg',
#   'coelbe',
#   'darmstadt',
#   'dautphetal',
#   'dieburg',
#   'diemelsee',
#   'diemelstadt',
#   'dietzenbach',
#   'dietzhoelztal',
#   'dillenburg',
#   'dipperz',
#   'dornburg',
#   'dreieich',
#   'driedorf',
#   'ebersburg',
#   'ebsdorfergrund',
#   'echzell',
#   'edermuende',
#   'edertal',
#   'egelsbach',
#   'ehrenberg',
#   'ehringshausen',
#   'eichenzell',
#   'einhausen',
#   'eiterfeld',
#   'elbtal',
#   'elz',
#   'eppertshausen',
#   'eppstein',
#   'erbach',
#   'erlensee',
#   'erzhausen',
#   'eschborn',
#   'eschenburg',
#   'eschwege',
#   'espenau',
#   'feldatal',
#   'felsberg',
#   'fernwald',
#   'fischbachtal',
#   'flieden',
#   'florstadt',
#   'floersbachtal',
#   'floersheimammain',
#   'frankenau',
#   'frankfurtammain',
#   'frauenstein',
#   'freiensteinau',
#   'freigericht',
#   'friedberg',
#   'friedberg(hessen)',
#   'friedewald',
#   'friedrichsdorf',
#   'frielendorf',
#   'fritzlar',
#   'fronhausen',
#   'fraenkisch-crumbach',
#   'fulda',
#   'fuldabrueck',
#   'fuldatal',
#   'gedern',
#   'geisenheim',
#   'gelnhausen',
#   'gernsheim',
#   'giessen',
#   'gilserberg',
#   'ginsheim-gustavsburg',
#   'gladenbach',
#   'glashuetten',
#   'glauburg',
#   'gorxheimertal',
#   'grasellenbach',
#   'grebenau',
#   'grebenhain',
#   'grebenstein',
#   'greifenstein',
#   'griesheim',
#   'gross-bieberau',
#   'gross-gerau',
#   'gross-rohrheim',
#   'gross-umstadt',
#   'gross-zimmern',
#   'grossenlueder',
#   'grosskrotzenburg',
#   'graevenwiesbach',
#   'gruenberg',
#   'gruendau',
#   'gudensberg',
#   'guxhagen',
#   'habichtswald',
#   'hadamar',
#   'haiger',
#   'haina',
#   'hainburg',
#   'hammersbach',
#   'hanau',
#   'hasselbach',
#   'hasselroth',
#   'hattersheimammain',
#   'hauneck',
#   'haunetal',
#   'heidenrod',
#   'herborn',
#   'herbstein',
#   'herleshausen',
#   'hessischlichtenau',
#   'heuchelheim',
#   'heusenstamm',
#   'hilders',
#   'hirzenhain',
#   'hofbieber',
#   'hofheim',
#   'hofheimamtaunus',
#   'hohenahr',
#   'hohenroda',
#   'homberg',
#   'hosenfeld',
#   'hungen',
#   'huenfeld',
#   'huenfelden',
#   'huenstetten',
#   'huettenberg',
#   'idstein',
#   'immenhausen',
#   'jesberg',
#   'jossgrund',
#   'kalbach',
#   'karben',
#   'kassel',
#   'kaufungen',
#   'kefenrod',
#   'kelkheim',
#   'kelkheim(taunus)',
#   'kelsterbach',
#   'kiedrich',
#   'kirchhain',
#   'kirtorf',
#   'knuellwald',
#   'korbach',
#   'kriftel',
#   'koenigstein',
#   'koerle',
#   'kuenzell',
#   'lahnau',
#   'lahntal',
#   'lampertheim',
#   'langen',
#   'langenselbold',
#   'langgoens',
#   'laubach',
#   'lauterbach',
#   'lautertal',
#   'leun',
#   'lich',
#   'liebenau',
#   'limburg',
#   'limeshain',
#   'linden',
#   'lindenfels',
#   'linsengericht',
#   'lohfelden',
#   'lohra',
#   'lollar',
#   'lorch',
#   'lorsch',
#   'ludwigsau',
#   'loehnberg',
#   'luetzelbach',
#   'mainhausen',
#   'maintal',
#   'malsfeld',
#   'marburg',
#   'meinhard',
#   'meissner',
#   'melsungen',
#   'mengerskirchen',
#   'merenberg',
#   'messel',
#   'michelstadt',
#   'mittenaar',
#   'modautal',
#   'morschen',
#   'mossautal',
#   'moerfelden-walldorf',
#   'moerlenbach',
#   'muecke',
#   'muehlheim',
#   'muehlheimammain',
#   'muehltal',
#   'muenchhausen',
#   'muenzenberg',
#   'nauheim',
#   'naumburg',
#   'neckarsteinach',
#   'nentershausen',
#   'neu-anspach',
#   'neu-eichenberg',
#   'neu-isenburg',
#   'neuberg',
#   'neuenstein',
#   'neuental',
#   'neukirchen',
#   'nidda',
#   'niddatal',
#   'nidderau',
#   'niedenstein',
#   'niederaula',
#   'niederdorfelden',
#   'niedernhausen',
#   'niedertiefenbach',
#   'nieste',
#   'niestetal',
#   'nuesttal',
#   'ober-moerlen',
#   'ober-ramstadt',
#   'oberaula',
#   'obertshausen',
#   'oberursel',
#   'oberursel(taunus)',
#   'oestrich-winkel',
#   'offenbach',
#   'offenbachammain',
#   'ortenberg',
#   'ottrau',
#   'otzberg',
#   'pfungstadt',
#   'pohlheim',
#   'ranstadt',
#   'rasdorf',
#   'raunheim',
#   'rauschenberg',
#   'reinhardshagen',
#   'reinheim',
#   'reiskirchen',
#   'riedstadt',
#   'ringgau',
#   'rockenberg',
#   'rodenbach',
#   'rodgau',
#   'romrod',
#   'ronneburg',
#   'ronshausen',
#   'rotenburg',
#   'rothenberg',
#   'rossdorf',
#   'runkel',
#   'roedermark',
#   'ruedesheim',
#   'ruesselsheim',
#   'schaafheim',
#   'schauenburg',
#   'schenklengsfeld',
#   'schlangenbad',
#   'schlitz',
#   'schluechtern',
#   'schmitten',
#   'schotten',
#   'schrecksbach',
#   'schwalmstadt',
#   'schwalmtal',
#   'schwarzenborn',
#   'schoeffengrund',
#   'seeheim-jugenheim',
#   'seligenstadt',
#   'sensbachtal',
#   'siegbach',
#   'sinn',
#   'sinntal',
#   'solms',
#   'sontra',
#   'spangenberg',
#   'sprendlingen',
#   'stadtallendorf',
#   'staufenberg',
#   'steffenberg',
#   'steinau',
#   'sulzbach',
#   'soehrewald',
#   'tann',
#   'taunusstein',
#   'trebur',
#   'trendelburg',
#   'twistetal',
#   'ulrichstein',
#   'usingen',
#   'vellmar',
#   'viernheim',
#   'villmar',
#   'volkmarsen',
#   'voehl',
#   'wabern',
#   'wahlsburg',
#   'wald-michelbach',
#   'waldbrunn',
#   'waldeck',
#   'waldems',
#   'waldkappel',
#   'waldsolms',
#   'walluf',
#   'wanfried',
#   'wartenberg',
#   'wehretal',
#   'weilburg',
#   'weilmuenster',
#   'weilrod',
#   'weinbach',
#   'weiterstadt',
#   'weissenborn',
#   'wettenberg',
#   'wetter',
#   'wetzlar',
#   'wiesbaden',
#   'wildeck',
#   'willingen',
#   'willingshausen',
#   'wohratal',
#   'wolfhagen',
#   'waechtersbach',
#   'woelfersheim',
#   'woellstadt',
#   'zwingenberg'],
#  'Mecklenburg-Vorpommern': ['admannshagen-bargeshagen',
#   'ahlbeck',
#   'altbukow',
#   'altkrenzlin',
#   'altmeteln',
#   'altschwerin',
#   'alttellin',
#   'altzachun',
#   'altefaehr',
#   'altenhagen',
#   'altenhof',
#   'altenkirchen',
#   'altenpleen',
#   'altentreptow',
#   'altkalen',
#   'altwigshagen',
#   'ankershagen',
#   'anklam',
#   'baabe',
#   'baddoberan',
#   'badsuelze',
#   'balow',
#   'bandelin',
#   'banzkow',
#   'barendorf',
#   'barnekow',
#   'barth',
#   'bartow',
#   'basedow',
#   'baumgarten',
#   'behrenhoff',
#   'bentwisch',
#   'benz',
#   'bergholz',
#   'bernitt',
#   'beseritz',
#   'bibow',
#   'blesewitz',
#   'blievenstorf',
#   'blumenhagen',
#   'boddin',
#   'bollewick',
#   'bredenfelde',
#   'broderstorf',
#   'bruenzow',
#   'bruesewitz',
#   'buddenhagen',
#   'burgstargard',
#   'buelow',
#   'cambs',
#   'cammin',
#   'damerow',
#   'dargen',
#   'demmin',
#   'deyelsdorf',
#   'dierhagen',
#   'diestelow',
#   'dorfmecklenburg',
#   'drechow',
#   'duemmer',
#   'eggesin',
#   'elmenhorst/lichtenhagen',
#   'franzburg',
#   'garz',
#   'gingst',
#   'glowe',
#   'gneven',
#   'graal-mueritz',
#   'greifswald',
#   'grieben',
#   'grimmen',
#   'grosskiesow',
#   'grosskordshagen',
#   'grossmiltzow',
#   'grosspolzin',
#   'grosswuestenfelde',
#   'goehren',
#   'guestrow',
#   'holthusen',
#   'iven',
#   'jarmen',
#   'karlshagen',
#   'karnin',
#   'koserow',
#   'krackow',
#   'kritzmow',
#   'kuehlungsborn',
#   'lalendorf',
#   'lambrechtshagen',
#   'laerz',
#   'marlow',
#   'neubrandenburg',
#   'neukalen',
#   'neustrelitz',
#   'papendorf',
#   'priepert',
#   'ribnitz-damgarten',
#   'roggentin',
#   'rostock',
#   'sassnitz',
#   'schwerin',
#   'stralsund',
#   'suederholz',
#   'ueckermuende',
#   'userin',
#   'waren(mueritz)',
#   'wismar',
#   'wokuhl-dabelow',
#   'woldegk',
#   'zinnowitz'],
#  'Niedersachsen': ['achim',
#   'adelebsen',
#   'adelheidsdorf',
#   'adenbuettel',
#   'adendorf',
#   'aerzen',
#   'affinghausen',
#   'agathenburg',
#   'ahlerstedt',
#   'ahnsbeck',
#   'ahnsen',
#   'alfhausen',
#   'alfstedt',
#   'algermissen',
#   'altenmedingen',
#   'amelinghausen',
#   'anderlingen',
#   'andervenne',
#   'ankum',
#   'apelern',
#   'apen',
#   'apensen',
#   'appel',
#   'appeln',
#   'arholzen',
#   'artlenburg',
#   'asendorf',
#   'auetal',
#   'auhagen',
#   'aurich',
#   'axstedt',
#   'badbederkesa',
#   'badbentheim',
#   'badbevensen',
#   'badbodenteich',
#   'badeilsen',
#   'badessen',
#   'badgandersheim',
#   'badharzburg',
#   'badiburg',
#   'badlaer',
#   'badnenndorf',
#   'badpyrmont',
#   'badrothenfelde',
#   'badsachsa',
#   'badsalzdetfurth',
#   'badzwischenahn',
#   'badbergen',
#   'baddeckenstedt',
#   'badenhausen',
#   'bahrdorf',
#   'bahrenborstel',
#   'bakum',
#   'balge',
#   'balje',
#   'baltrum',
#   'banteln',
#   'bardowick',
#   'bargstedt',
#   'barnstedt',
#   'barnstorf',
#   'barsinghausen',
#   'barum',
#   'barver',
#   'barwedel',
#   'barssel',
#   'bassum',
#   'bawinkel',
#   'beckdorf',
#   'beckedorf',
#   'beckeln',
#   'beedenbostel',
#   'beierstedt',
#   'belm',
#   'belum',
#   'bergfeld',
#   'berne',
#   'bersenbrueck',
#   'betheln',
#   'betzendorf',
#   'bevern',
#   'bienenbuettel',
#   'bispingen',
#   'bissendorf',
#   'blender',
#   'bliedersdorf',
#   'bockenem',
#   'bockhorn',
#   'bockhorst',
#   'bodenfelde',
#   'bodenwerder',
#   'boffzen',
#   'bohmte',
#   'boitze',
#   'bokensdorf',
#   'bomlitz',
#   'borkum',
#   'borstel',
#   'bothel',
#   'bovenden',
#   'brackel',
#   'bramsche',
#   'bramstedt',
#   'braunschweig',
#   'breddorf',
#   'brevoerde',
#   'brietlingen',
#   'brinkum',
#   'brockum',
#   'brome',
#   'bruchhausen-vilsen',
#   'brunsleberfeld',
#   'broeckel',
#   'buchholz',
#   'burgdorf',
#   'burgwedel',
#   'burweg',
#   'buxtehude',
#   'boerger',
#   'boesel',
#   'bueckeburg',
#   'buecken',
#   'bueddenstedt',
#   'buehren',
#   'buelkau',
#   'cadenberge',
#   'calberlah',
#   'cappel',
#   'celle',
#   'clausthal-zellerfeld',
#   'clenze',
#   'cloppenburg',
#   'coppengrave',
#   'cremlingen',
#   'cuxhaven',
#   'damme',
#   'danndorf',
#   'dedelstorf',
#   'deinste',
#   'delligsen',
#   'delmenhorst',
#   'denkte',
#   'dersum',
#   'despetal',
#   'detern',
#   'dettum',
#   'deutschevern',
#   'didderse',
#   'diekholzen',
#   'dielmissen',
#   'diepenau',
#   'diepholz',
#   'dinklage',
#   'dohren',
#   'dollern',
#   'dornum',
#   'drage',
#   'drakenburg',
#   'drebber',
#   'duderstadt',
#   'duingen',
#   'dunum',
#   'doerpen',
#   'doerverden',
#   'doetlingen',
#   'ebergoetzen',
#   'echem',
#   'edemissen',
#   'edewecht',
#   'egestorf',
#   'ehra-lessien',
#   'ehrenburg',
#   'eicklingen',
#   'eime',
#   'eimen',
#   'eimke',
#   'einbeck',
#   'elbe',
#   'eldingen',
#   'elsfleth',
#   'elze',
#   'embsen',
#   'emden',
#   'emlichheim',
#   'emmendorf',
#   'emmerthal',
#   'emsbueren',
#   'emtinghausen',
#   'engden',
#   'engelschoff',
#   'esche',
#   'eschede',
#   'estorf',
#   'eversmeer',
#   'eyendorf',
#   'fassberg',
#   'filsum',
#   'fintel',
#   'frankenfeld',
#   'freistatt',
#   'frellstedt',
#   'fresenburg',
#   'friedeburg',
#   'friedland',
#   'friesoythe',
#   'fuerstenau',
#   'fuerstenberg',
#   'ganderkesee',
#   'garbsen',
#   'garrel',
#   'garstedt',
#   'gartow',
#   'geeste',
#   'gehrde',
#   'gehrden',
#   'georgsmarienhuette',
#   'gersten',
#   'getelo',
#   'gevensleben',
#   'geversdorf',
#   'gielde',
#   'giesen',
#   'gifhorn',
#   'glandorf',
#   'gleichen',
#   'gnarrenburg',
#   'goldenstedt',
#   'golmbach',
#   'gorleben',
#   'goslar',
#   'grafhorst',
#   'grasberg',
#   'grasleben',
#   'grossberssen',
#   'grossmeckelsen',
#   'grossoesingen',
#   'grosstwuelpstedt',
#   'grossefehn',
#   'grossenkneten',
#   'grossenwoerden',
#   'grossheide',
#   'gusborn',
#   'goehrde',
#   'goettingen',
#   'habighorst',
#   'hagenburg',
#   'hahausen',
#   'halvesbostel',
#   'hambuehren',
#   'hameln',
#   'handeloh',
#   'handorf',
#   'hann.muenden',
#   'hannover',
#   'hanstedt',
#   'hardegsen',
#   'haren(ems)',
#   'harsum',
#   'hasbergen',
#   'haseluenne',
#   'haste',
#   'hatten',
#   'haverlah',
#   'hechthausen',
#   'hedeper',
#   'heemsen',
#   'heinbockel',
#   'heinsen',
#   'helmstedt',
#   'helpsen',
#   'hemmoor',
#   'hermannsburg',
#   'hespe',
#   'hessischoldendorf',
#   'heuerssen',
#   'hildesheim',
#   'hilgermissen',
#   'hillerse',
#   'himbergen',
#   'hinte',
#   'hittbergen',
#   'hohenhameln',
#   'holdorf',
#   'holenberg',
#   'hollern-twielenfleth',
#   'holzminden',
#   'hoogstede',
#   'hoyershausen',
#   'hude',
#   'huelsede',
#   'hueven',
#   'ihlienworth',
#   'ihlow',
#   'ilsede',
#   'ingeleben',
#   'isenbuettel',
#   'isernhagen',
#   'itterbeck',
#   'jade',
#   'jameln',
#   'jelmstorf',
#   'jembke',
#   'jemgum',
#   'jerxheim',
#   'jesteburg',
#   'juist',
#   'kalefeld',
#   'karwitz',
#   'katlenburg-lindau',
#   'kirchgellersen',
#   'kirchlinteln',
#   'kissenbrueck',
#   'kreiensen',
#   'krummendeich',
#   'krummhoern',
#   'kutenholz',
#   'kuesten',
#   'laatzen',
#   'lachendorf',
#   'lahn',
#   'lahstedt',
#   'lamspringe',
#   'landesbergen',
#   'landwehr',
#   'langelsheim',
#   'langendorf',
#   'langenhagen',
#   'langeoog',
#   'langwedel',
#   'lastrup',
#   'lauenhagen',
#   'leese',
#   'leezdorf',
#   'lehre',
#   'lehrte',
#   'leiferde',
#   'lemgow',
#   'lemwerder',
#   'lengede',
#   'liebenburg',
#   'lilienthal',
#   'lingen(ems)',
#   'lohne(oldenburg)',
#   'lorup',
#   'loxstedt',
#   'luckau',
#   'luhden',
#   'laehden',
#   'loeningen',
#   'luebbow',
#   'luechow',
#   'lueder',
#   'luedersfeld',
#   'lueerdissen',
#   'lueneburg',
#   'maasen',
#   'marienhagen',
#   'marklohe',
#   'marschacht',
#   'martfeld',
#   'marxen',
#   'mechtersen',
#   'meerbeck',
#   'meine',
#   'meinersen',
#   'melle',
#   'meppen',
#   'merzen',
#   'mittelstenahe',
#   'moisburg',
#   'moormerland',
#   'moringen',
#   'nahrendorf',
#   'natendorf',
#   'negenborn',
#   'neudarchau',
#   'neuwulmstorf',
#   'neuboerger',
#   'neuenkirchen-voerden',
#   'neustadtamruebenberge',
#   'niederlangen',
#   'niedernwoehren',
#   'nienhagen',
#   'nienstaedt',
#   'norden',
#   'nordenham',
#   'norderney',
#   'nordholz',
#   'nordhorn',
#   'nordleda',
#   'nordsehl',
#   'nordstemmen',
#   'northeim',
#   'nortmoor',
#   'nortrup',
#   'noerten-hardenberg',
#   'obernkirchen',
#   'ochtersum',
#   'oetzen',
#   'oldenburg',
#   'osloss',
#   'osnabrueck',
#   'osten',
#   'osterbruch',
#   'ostercappeln',
#   'osterholz-scharmbeck',
#   'osterodeamharz',
#   'ostrhauderfehn',
#   'ottenstein',
#   'otter',
#   'ottersberg',
#   'ovelgoenne',
#   'oyten',
#   'papenburg',
#   'pattensen',
#   'peine',
#   'pennigsehl',
#   'pollhagen',
#   'quakenbrueck',
#   'radbruch',
#   'raddestorf',
#   'rastede',
#   'regesbostel',
#   'rehburg-loccum',
#   'reinstorf',
#   'rhauderfehn',
#   'rheden',
#   'riede',
#   'rieste',
#   'rinteln',
#   'ritterhude',
#   'rodewald',
#   'rohrsen',
#   'roklum',
#   'ronnenberg',
#   'rosche',
#   'rosdorf',
#   'rosengarten',
#   'raebke',
#   'raetzlingen',
#   'roemstedt',
#   'roetgesbuettel',
#   'salzbergen',
#   'salzgitter',
#   'salzhemmendorf',
#   'sande',
#   'sarstedt',
#   'sassenburg',
#   'saterland',
#   'sauensiek',
#   'scheessel',
#   'schiffdorf',
#   'schnackenburg',
#   'schnega',
#   'schortens',
#   'schwafoerden',
#   'schwanewede',
#   'schwienau',
#   'schwuelper',
#   'schoeningen',
#   'seelze',
#   'seevetal',
#   'sehlde',
#   'sehlem',
#   'sehnde',
#   'semmenstedt',
#   'siedenburg',
#   'soltau',
#   'soltendieck',
#   'spiekeroog',
#   'sprakensehl',
#   'springe',
#   'stade',
#   'stadensen',
#   'stadland',
#   'stadthagen',
#   'steimbke',
#   'steinfeld',
#   'steinhorst',
#   'stelle',
#   'stinstedt',
#   'stoetze',
#   'stolzenau',
#   'stuhr',
#   'stoeckse',
#   'suhlendorf',
#   'sulingen',
#   'surwold',
#   'suthfeld',
#   'syke',
#   'soehlde',
#   'soellingen',
#   'suedbrookmerland',
#   'suepplingenburg',
#   'tappenbeck',
#   'tespe',
#   'thomasburg',
#   'toppenstedt',
#   'trebel',
#   'twieflingen',
#   'twist',
#   'twistringen',
#   'tuelau',
#   'uchte',
#   'uelzen',
#   'uetze',
#   'ummern',
#   'undeloh',
#   'unterluess',
#   'uplengen',
#   'varel',
#   'vechelde',
#   'vechta',
#   'velpke',
#   'verden(aller)',
#   'visbek',
#   'visselhoevede',
#   'voltlage',
#   'vordorf',
#   'waddeweitz',
#   'wagenfeld',
#   'wahrenholz',
#   'walchum',
#   'wallenhorst',
#   'walsrode',
#   'wangerland',
#   'wangerooge',
#   'wanna',
#   'warberg',
#   'wardenburg',
#   'warmsen',
#   'wasbuettel',
#   'wathlingen',
#   'wedemark',
#   'weener',
#   'weenzen',
#   'welle',
#   'wendeburg',
#   'wendischevern',
#   'wesendorf',
#   'weste',
#   'westerstede',
#   'westoverledingen',
#   'weyhausen',
#   'weyhe',
#   'wieda',
#   'wiedensahl',
#   'wiefelstede',
#   'wienhausen',
#   'wieren',
#   'wiesmoor',
#   'wietmarschen',
#   'wietze',
#   'wietzen',
#   'wietzendorf',
#   'wildemann',
#   'wildeshausen',
#   'wilhelmshaven',
#   'wilsum',
#   'wingst',
#   'winsen',
#   'winzenburg',
#   'wischhafen',
#   'wittingen',
#   'wittmar',
#   'wittmund',
#   'wolfenbuettel',
#   'wolfsburg',
#   'wolsdorf',
#   'woltershausen',
#   'wremen',
#   'wrestedt',
#   'wulfsen',
#   'wunstorf',
#   'wustrow',
#   'woelpinghausen',
#   'zernien',
#   'zetel',
#   'zorge'],
#  'Nordrhein-Westfalen': ['aachen',
#   'ahaus',
#   'ahlen',
#   'aldenhoven',
#   'alfter',
#   'alpen',
#   'alsdorf',
#   'altena',
#   'altenbeken',
#   'altenberge',
#   'anroechte',
#   'arnsberg',
#   'ascheberg',
#   'attendorn',
#   'augustdorf',
#   'badberleburg',
#   'baddriburg',
#   'badhonnef',
#   'badlaasphe',
#   'badlippspringe',
#   'badmuenstereifel',
#   'badoeynhausen',
#   'badsalzuflen',
#   'badsassendorf',
#   'badwuennenberg',
#   'baesweiler',
#   'balve',
#   'barntrup',
#   'beckum',
#   'bedburg',
#   'bedburg-hau',
#   'beelen',
#   'bergheim',
#   'bergischgladbach',
#   'bergkamen',
#   'bergneustadt',
#   'bestwig',
#   'beverungen',
#   'bielefeld',
#   'billerbeck',
#   'blankenheim',
#   'blomberg',
#   'bocholt',
#   'bochum',
#   'bonn',
#   'borchen',
#   'borgentreich',
#   'borgholzhausen',
#   'borken',
#   'bornheim',
#   'bottrop',
#   'brakel',
#   'breckerfeld',
#   'brilon',
#   'brueggen',
#   'bruehl',
#   'burbach',
#   'burscheid',
#   'boenen',
#   'buende',
#   'bueren',
#   'castrop-rauxel',
#   'coesfeld',
#   'dahlem',
#   'datteln',
#   'delbrueck',
#   'detmold',
#   'dinslaken',
#   'dormagen',
#   'dorsten',
#   'dortmund',
#   'drensteinfurt',
#   'drolshagen',
#   'duisburg',
#   'doerentrup',
#   'duelmen',
#   'dueren',
#   'duesseldorf',
#   'eitorf',
#   'elsdorf',
#   'emmerich',
#   'emmerichamrhein',
#   'emsdetten',
#   'engelskirchen',
#   'enger',
#   'ennepetal',
#   'ennigerloh',
#   'ense',
#   'erftstadt',
#   'erkelenz',
#   'erkrath',
#   'erndtebrueck',
#   'erwitte',
#   'eschweiler',
#   'espelkamp',
#   'essen',
#   'euskirchen',
#   'everswinkel',
#   'extertal',
#   'finnentrop',
#   'frechen',
#   'freudenberg',
#   'froendenberg/ruhr',
#   'gangelt',
#   'geilenkirchen',
#   'geldern',
#   'gelsenkirchen',
#   'gescher',
#   'geseke',
#   'gevelsberg',
#   'gladbeck',
#   'goch',
#   'grefrath',
#   'greven',
#   'grevenbroich',
#   'gronau',
#   'gronau(westf.)',
# ...
#   'oberhonnefeld-gierend',
#   'oberlahr',
#   'oberstreit',
#   'oberweiler-tiefenbach',
#   'oberwesel',
#   'obrigheim',
#   'onsdorf',
#   'osthofen',
#   'otterberg',
#   'otterstadt',
#   'piesport',
#   'pirmasens',
#   'plaidt',
#   'puenderich',
#   'ramstein-miesenbach',
#   'reifenberg',
#   'reil',
#   'rheinbreitbach',
#   'rheinzabern',
#   'rieschweiler-muehlbach',
#   'riesweiler',
#   'rodalben',
#   'ruppertsberg',
#   'roedersheim-gronau',
#   'roemerberg',
#   'ruelzheim',
#   'saffig',
#   'salmtal',
#   'saulheim',
#   'schallodenbach',
#   'scheuerfeld',
#   'schifferstadt',
#   'schmalenberg',
#   'schwarzerden',
#   'schwegenheim',
#   'schoenenberg-kuebelberg',
#   'schueller',
#   'sembach',
#   'serrig',
#   'siershahn',
#   'simmertal',
#   'sinzig',
#   'sippersfeld',
#   'spangdahlem',
#   'spay',
#   'speyer',
#   'stadecken-elsheim',
#   'thaleischweiler-froeschen',
#   'treis-karden',
#   'trier',
#   'trierweiler',
#   'trittenheim',
#   'urbar',
#   'wackernheim',
#   'waldalgesheim',
#   'waldmohr',
#   'waldrach',
#   'waldsee',
#   'wasserliesch',
#   'weidenthal',
#   'weitefeld',
#   'weitersburg',
#   'weissenthurm',
#   'westheim',
#   'willroth',
#   'wiltingen',
#   'wincheringen',
#   'windhagen',
#   'winningen',
#   'winnweiler',
#   'wintersheim',
#   'winterspelt',
#   'wintrich',
#   'wirges',
#   'worms',
#   'zeiskam',
#   'zemmer',
#   'zweibruecken',
#   'uerzig',
#   'uexheim'],
#  'Saarland': ['beckingen',
#   'bexbach',
#   'blieskastel',
#   'bous',
#   'dillingen/saar',
#   'ensdorf',
#   'eppelborn',
#   'freisen',
#   'friedrichsthal',
#   'gersheim',
#   'grossrosseln',
#   'heusweiler',
#   'homburg',
#   'illingen',
#   'kirkel',
#   'kleinblittersdorf',
#   'lebach',
#   'mandelbachtal',
#   'marpingen',
#   'merzig',
#   'mettlach',
#   'nalbach',
#   'namborn',
#   'neunkirchen',
#   'nohfelden',
#   'nonnweiler',
#   'oberthal',
#   'ottweiler',
#   'perl',
#   'puettlingen',
#   'quierschied',
#   'rehlingen',
#   'rehlingen-siersburg',
#   'riegelsberg',
#   'saarbruecken',
#   'saarlouis',
#   'saarwellingen',
#   'schiffweiler',
#   'schmelz',
#   'schwalbach',
#   'spiesen-elversberg',
#   'st.ingbert',
#   'st.wendel',
#   'tholey',
#   'voelklingen',
#   'wadern',
#   'wadgassen',
#   'wallerfangen',
#   'weiskirchen',
#   'ueberherrn'],
#  'Sachsen': ['adorf/vogtl.',
#   'altenberg',
#   'altmittweida',
#   'amtsberg',
#   'annaberg-buchholz',
#   'arnsdorf',
#   'aue',
#   'augustusburg',
#   'badbrambach',
#   'badelster',
#   'badlausick',
#   'badmuskau',
#   'badschandau',
#   'bahretal',
#   'bannewitz',
#   'bautzen',
#   'beilrode',
#   'belgern',
#   'belgershain',
#   'bernsbach',
#   'bernsdorf',
#   'bernstadt',
#   'berthelsdorf',
#   'bertsdorf-hoernitz',
#   'bischofswerda',
#   'bobritzsch',
#   'bockau',
#   'bockelwitz',
#   'borna',
#   'borsdorf',
#   'borstendorf',
#   'boxberg',
#   'brand-erbisdorf',
#   'brandis',
#   'breitenbrunn',
#   'bretnig-hauswalde',
#   'burgstaedt',
#   'burkau',
#   'burkhardtsdorf',
#   'baerenstein',
#   'boehlen',
#   'callenberg',
#   'cavertitz',
#   'chemnitz',
#   'claussnitz',
#   'colditz',
#   'coswig',
#   'crimmitschau',
#   'crinitzberg',
#   'crottendorf',
#   'cunewalde',
#   'dahlen',
#   'delitzsch',
#   'dennheritz',
#   'deutzen',
#   'dippoldiswalde',
#   'doberschau-gaussig',
#   'doberschuetz',
#   'dohma',
#   'dohna',
#   'dommitzsch',
#   'dorfchemnitz',
#   'drebach',
#   'dreiheide',
#   'dresden',
#   'doebeln',
#   'duerrhennersdorf',
#   'duerrroehrsdorf-dittersbach',
#   'ebersbach-neugersdorf',
#   'ehrenfriedersdorf',
#   'eibau',
#   'eibenstock',
#   'eichigt',
#   'eilenburg',
#   'ellefeld',
#   'elsterberg',
#   'elstertrebnitz',
#   'elterlein',
#   'eppendorf',
#   'erlabrunn',
#   'erlau',
#   'erlbach-kirchberg',
#   'espenhain',
#   'falkenau',
#   'falkenstein',
#   'floeha',
#   'fraureuth',
#   'freiberg',
#   'freital',
#   'friedersdorf',
#   'frohburg',
#   'geithain',
#   'geringswalde',
#   'gersdorf',
#   'geyer',
#   'glashuette',
#   'glaubitz',
#   'glauchau',
#   'gohrisch',
#   'gornsdorf',
#   'grimma',
#   'groitzsch',
#   'grossdubrau',
#   'grossenhain',
#   'grossnaundorf',
#   'grossolbersdorf',
#   'grosspoesna',
#   'grossroehrsdorf',
#   'grossrueckerswalde',
#   'grossschoenau',
#   'grossweitzschen',
#   'groeditz',
#   'gruenhainichen',
#   'goerlitz',
#   'hainichen',
#   'halsbruecke',
#   'hartha',
#   'hartmannsdorf',
#   'hartmannsdorf-reichenau',
#   'haselbachtal',
#   'heidenau',
#   'heidersdorf',
#   'heinsdorfergrund',
#   'hermsdorf',
#   'hochkirch',
#   'hohendubrau',
#   'hohenstein-ernstthal',
#   'hohndorf',
#   'hohnstein',
#   'hormersdorf',
#   'hoyerswerda',
#   'haehnichen',
#   'hoeckendorf',
#   'jesewitz',
#   'johanngeorgenstadt',
#   'kamenz',
#   'kirchberg',
#   'kittlitz',
#   'kitzen',
#   'kitzscher',
#   'klingenthal',
#   'klipphausen',
#   'kodersdorf',
#   'kohren-sahlis',
#   'krauschwitz',
#   'kreba-neudorf',
#   'kreischa',
#   'krostitz',
#   'koenigshain',
#   'koenigswartha',
#   'lampertswalde',
#   'langenbernsdorf',
#   'langenweissbach',
#   'lauta',
#   'laussig',
#   'leipzig',
#   'leisnig',
#   'lengefeld',
#   'lengenfeld',
#   'leubsdorf',
#   'leutersdorf',
#   'lichtenstein',
#   'lichtentanne',
#   'liebschuetzberg',
#   'limbach',
#   'limbach-oberfrohna',
#   'lohmen',
#   'lommatzsch',
#   'lunzenau',
#   'loebau',
#   'loessnitz',
#   'machern',
#   'malschwitz',
#   'marienberg',
#   'markkleeberg',
#   'markranstaedt',
#   'meerane',
#   'meissen',
#   'mildenau',
#   'mittweida',
#   'mochau',
#   'moritzburg',
#   'muldenhammer',
#   'mylau',
#   'muegeln',
#   'mueglitztal',
#   'muehlau',
#   'muelsen',
#   'narsdorf',
#   'naundorf',
#   'naunhof',
#   'netzschkau',
#   'neukieritzsch',
#   'neukirch',
#   'neukirch/lausitz',
#   'neukirchen/pleisse',
#   'neukyhna',
#   'neumark',
#   'niederau',
#   'niederdorf',
#   'niederfrohna',
#   'niederstriegis',
#   'niederwiesa',
#   'niederwuerschnitz',
#   'niesky',
#   'nossen',
#   'obergurig',
#   'oberlungwitz',
#   'oberschoena',
#   'oberwiera',
#   'oberwiesenthal',
#   'oderwitz',
#   'oederan',
#   'ohorn',
#   'olbernhau',
#   'olbersdorf',
#   'oppach',
#   'oschatz',
#   'ostrau',
#   'ostritz',
#   'ottendorf-okrilla',
#   'otterwisch',
#   'oybin',
#   'ossling',
#   'pausa/vogtl.',
#   'pegau',
#   'penig',
#   'pirna',
#   'plauen',
#   'pockau',
#   'priestewitz',
#   'pulsnitz',
#   'poehl',
#   'rabenau',
#   'rackwitz',
#   'radeberg',
#   'radebeul',
#   'radeburg',
#   'radibor',
#   'rathmannsdorf',
#   'rechenberg-bienenmuehle',
#   'regis-breitingen',
#   'reinsdorf',
#   'remse',
#   'riesa',
#   'rietschen',
#   'rochlitz',
#   'rodewisch',
#   'rosenthal',
#   'rosswein',
#   'roetha',
#   'sandberg',
#   'sayda',
#   'scheibenberg',
#   'schkeuditz',
#   'schlettau',
#   'schneeberg',
#   'schwepnitz',
#   'schoenbach',
#   'schoeneck',
#   'schoenheide',
#   'seelitz',
#   'sehmatal',
#   'seifhennersdorf',
#   'speicher',
#   'st.egidien',
#   'stadtwehlen',
#   'stauchitz',
#   'steinberg',
#   'steinigtwolmsdorf',
#   'strehla',
#   'striegistal',
#   'stuetzengruen',
#   'taucha',
#   'taura',
#   'tauscha',
#   'thallwitz',
#   'thum',
#   'torgau',
#   'treuen',
#   'triebischtal',
#   'trossin',
#   'waldenburg',
#   'waldheim',
#   'waltersdorf',
#   'weinboehla',
#   'weissenberg',
#   'weisswasser/o.l.',
#   'werdau',
#   'wermsdorf',
#   'wiedemar',
#   'wildenfels',
#   'wilkau-hasslau',
#   'wilsdruff',
#   'wurzen',
#   'wuelknitz',
#   'zettlitz',
#   'zittau',
#   'zschaitz-ottewig',
#   'zschopau',
#   'zschorlau',
#   'zwenkau',
#   'zwickau',
#   'zwota',
#   'zwoenitz',
#   'zoeblitz'],
#  'Sachsen-Anhalt': ['aland',
#   'angern',
#   'annaburg',
#   'aschersleben',
#   'ausleben',
#   'badbibra',
#   'badduerrenberg',
#   'badlauchstaedt',
#   'badschmiedeberg',
#   'balgstaedt',
#   'ballenstedt',
#   'barby',
#   'beetzendorf',
#   'bergisdorf',
#   'bernburg(saale)',
#   'biederitz',
#   'bitterfeld-wolfen',
#   'blankenburg',
#   'blankenburg(harz)',
#   'borne',
#   'braunsbedra',
#   'burg',
#   'boerdeland',
#   'calvoerde',
#   'colbitz',
#   'dessau',
#   'dessau-rosslau',
#   'diesdorf',
#   'ditfurt',
#   'droyssig',
#   'egeln',
#   'eilsleben',
#   'eisleben',
#   'elbe-parey',
#   'erxleben',
#   'finneland',
#   'gardelegen',
#   'genthin',
#   'gerbstedt',
#   'goldbeck',
#   'gommern',
#   'graefenhainichen',
#   'groeningen',
#   'gutenberg',
#   'guesten',
#   'halberstadt',
#   'haldensleben',
#   'halle(saale)',
#   'harsleben',
#   'harzgerode',
#   'havelberg',
#   'hecklingen',
#   'hedersleben',
#   'helbra',
#   'hergisdorf',
#   'hettstedt',
#   'hohenmoelsen',
#   'huy',
#   'hoetensleben',
#   'ilberstedt',
#   'jerichow',
#   'kabelsketal',
#   'kalbe',
#   'karsdorf',
#   'kemberg',
#   'klietz',
#   'klostermansfeld',
#   'kloetze',
#   'kretzschau',
#   'kroppenstedt',
#   'kuhfelde',
#   'koennern',
#   'koethen(anhalt)',
#   'landsberg',
#   'leuna',
#   'luetzen',
#   'magdeburg',
#   'mansfeld',
#   'merseburg',
#   'mertendorf',
#   'moeckern',
#   'moeser',
#   'muecheln',
#   'naumburg(saale)',
#   'nienburg',
#   'oranienbaum-woerlitz',
#   'oschersleben(bode)',
#   'osterfeld',
#   'osterwieck',
#   'petersberg',
#   'ploetzkau',
#   'quedlinburg',
#   'raguhn-jessnitz',
#   'rogaetz',
#   'rohrberg',
#   'salzatal',
#   'salzwedel',
#   'sangerhausen',
#   'schkopau',
#   'schollene',
#   'schwanebeck',
#   'schoenhausen',
#   'sommersdorf',
#   'stassfurt',
#   'stendal',
#   'stoessen',
#   'suedharz',
#   'teuchern',
#   'teutschenthal',
#   'thale',
#   'voelpke',
#   'wallstawe',
#   'wanzleben-boerde',
#   'wegeleben',
#   'weissenfels',
#   'wernigerode',
#   'wittenberg',
#   'wolmirsleben',
#   'wolmirstedt',
#   'zahna-elster',
#   'zeitz'],
#  'Schleswig-Holstein': ['achterwehr',
#   'achtrup',
#   'aebtissinwisch',
#   'ahneby',
#   'ahrensburg',
#   'ahrensboek',
#   'ahrenshoeft',
#   'ahrenvioel',
#   'albersdorf',
#   'albsfelde',
#   'alkersum',
#   'almdorf',
#   'altbennebek',
#   'altmoelln',
#   'altenholz',
#   'altenkrempe',
#   'altenmoor',
#   'alveslohe',
#   'ammersbek',
#   'appen',
#   'armstedt',
#   'arnis',
#   'arpsdorf',
#   'ascheffel',
#   'aukrug',
#   'ausacker',
#   'auufer',
#   'aventoft',
#   'averlak',
#   'badbramstedt',
#   'badoldesloe',
#   'badschwartau',
#   'badsegeberg',
#   'badendorf',
#   'bahrenfleth',
#   'bargenstedt',
#   'bargfeld-stegen',
#   'bargstall',
#   'bargteheide',
#   'barkelsby',
#   'barkenholm',
#   'barlt',
#   'barmissen',
#   'barnitz',
#   'barsbek',
#   'barsbuettel',
#   'basthorst',
#   'bebensee',
#   'behlendorf',
#   'behrendorf',
#   'beidenfleth',
#   'bekdorf',
#   'bekmuende',
#   'beldorf',
#   'bergenhusen',
#   'bergewoehrden',
#   'beringstedt',
#   'beschendorf',
#   'besdorf',
#   'besenthal',
#   'bilsen',
#   'bissee',
#   'blekendorf',
#   'bliestorf',
#   'blomeschewildnis',
#   'blumenthal',
#   'blunk',
#   'bokel',
#   'bokholt-hanredder',
#   'bollingstedt',
#   'boostedt',
#   'bordelum',
#   'borgdorf-seedorf',
#   'borgstedt',
#   'borgwedel',
#   'bornholt',
#   'bornhoeved',
#   'borsfleth',
#   'borstel-hohenraden',
#   'bosau',
#   'bosbuell',
#   'bothkamp',
#   'bovenau',
#   'braak',
#   'braderup',
#   'bramstedtlund',
#   'brande-hoernerkirchen',
#   'breitenberg',
#   'brickeln',
#   'brodersby',
#   'brodersdorf',
#   'brokdorf',
#   'brunsbek',
#   'brunsbuettel',
#   'brunstorf',
#   'broethen',
#   'buchhorst',
#   'busdorf',
#   'boeel',
#   'boehnhusen',
#   'boeklund',
#   'boenebuettel',
#   'boenningstedt',
#   'boernsen',
#   'boexlund',
#   'buedelsdorf',
#   'buesum',
#   'christiansholm',
#   'christinenthal',
#   'dahme',
#   'daldorf',
#   'damendorf',
#   'damp',
#   'dannau',
#   'dannewerk',
#   'dassendorf',
#   'dellstedt',
#   'delve',
#   'diekhusen-fahrstedt',
#   'dobersdorf',
#   'dollerup',
#   'duvensee',
#   'daegeling',
#   'daenischenhagen',
#   'doerpling',
#   'doerpstedt',
#   'eckernfoerde',
#   'eggebek',
#   'eggstedt',
#   'ehndorf',
#   'elisabeth-sophien-koog',
#   'ellerau',
#   'ellerbek',
#   'ellerhoop',
#   'ellingstedt',
#   'elmenhorst',
#   'elmshorn',
#   'elsdorf-westermuehlen',
#   'elskop',
#   'embuehren',
#   'emmelsbuell-horsbuell',
#   'erfde',
#   'eutin',
#   'fahren',
#   'fargau-pratjau',
#   'felde',
#   'felm',
#   'fitzbek',
#   'fleckeby',
#   'flensburg',
#   'freienwill',
#   'fresendelf',
#   'frestedt',
#   'friedrichsgabekoog',
#   'fuhlendorf',
#   'garding',
#   'gaushorn',
#   'geesthacht',
#   'gelting',
#   'geltorf',
#   'geschendorf',
#   'glasau',
#   'glinde',
#   'gnutz',
#   'goldebek',
#   'groven',
#   'grossgroenau',
#   'grosskummerfeld',
#   'grossnordende',
#   'grossschenkenberg',
#   'grossenaspe',
#   'grossenbrode',
#   'grossenwiehe',
#   'grosshansdorf',
#   'grossharrie',
#   'grube',
#   'grundhof',
#   'groedersby',
#   'groemitz',
#   'groenwohld',
#   'goehl',
#   'goennebek',
#   'halstenbek',
#   'hamdorf',
#   'handewitt',
#   'harrislee',
#   'hartenholm',
#   'haselau',
#   'haseldorf',
#   'haselund',
#   'hasloh',
#   'hattstedt',
#   'havetoft',
#   'havetoftloit',
#   'hassmoor',
#   'heide',
#   'heidgraben',
#   'heidmoor',
#   'heikendorf',
#   'heiligenhafen',
#   'heist',
#   'helgoland',
#   'hemmingstedt',
#   'hennstedt',
#   'henstedt-ulzburg',
#   'heringsdorf',
#   'herzhorn',
#   'hetlingen',
#   'hohenfelde',
#   'hohenhorn',
#   'hohenlockstedt',
#   'hoisdorf',
#   'hollingstedt',
#   'holm',
#   'holtsee',
#   'holzdorf',
#   'honigsee',
#   'horst',
#   'huje',
#   'husum',
#   'hoegel',
#   'hoerup',
#   'huesby',
#   'huettblek',
#   'itzehoe',
#   'itzstedt',
#   'jagel',
#   'janneby',
#   'jerrishoe',
#   'jersbek',
#   'jevenstedt',
#   'kaltenkirchen',
#   'kiebitzreihe',
#   'kiel',
#   'kirchnuechel',
#   'kisdorf',
#   'kleinoffenseth-sparrieshoop',
#   'klempau',
#   'kollmar',
#   'kollow',
#   'kremsii',
#   'krogaspe',
#   'kronshagen',
#   'kroeppelshagen-fahrendorf',
#   'kuddewoerde',
#   'kummerfeld',
#   'koelln-reisiek',
#   'koenigswill',
#   'kuekels',
#   'lammershagen',
#   'linau',
#   'loose',
#   'laegerdorf',
#   'loewenstedt',
#   'luebeck',
#   'luetjensee',
#   'maasholm',
#   'mielkendorf',
#   'mildstedt',
#   'moorrege',
#   'moenkeberg',
#   'muensterdorf',
#   'muessen',
#   'nahe',
#   'nebel',
#   'neuendeich',
#   'neuengoers',
#   'neufeld',
#   'neumuenster',
#   'norderfriedrichskoog',
#   'norderstedt',
#   'nordhastedt',
#   'norstedt',
#   'nusse',
#   'nutteln',
#   'nuebbel',
#   'nuebel',
#   'oeversee',
#   'oldersbek',
#   'osdorf',
#   'osterby',
#   'osterstedt',
#   'oststeinbek',
#   'ottenbuettel',
#   'pinneberg',
#   'prisdorf',
#   'pronstorf',
#   'quern',
#   'quickborn',
#   'ratekau',
#   'reinbek',
#   'rellingen',
#   'rendsburg',
#   'risum-lindholm',
#   'rohlstorf',
#   'rumohr',
#   'ruede',
#   'sanktpeter-ording',
#   'scharbeutz',
#   'schenefeld',
#   'schleswig',
#   'schmalensee',
#   'schwarzenbek',
#   'schoenwalde',
#   'schuelp',
#   'seedorf',
#   'seester',
#   'seestermuehe',
#   'sehestedt',
#   'siek',
#   'sieverstedt',
#   'stapelfeld',
#   'steinburg',
#   'stelle-wittenwurth',
#   'stockelsdorf',
#   'stolk',
#   'struvenhuetten',
#   'soerup',
#   'suederstapel',
#   'suelfeld',
#   'taarstedt',
#   'tangstedt',
#   'tetenbuell',
#   'tetenhusen',
#   'todendorf',
#   'tornesch',
#   'tremsbuettel',
#   'uelvesbuell',
#   'uetersen',
#   'ulsnis',
#   'waabs',
#   'wanderup',
#   'warder',
#   'wedel',
#   'wees',
#   'westensee',
#   'wewelsfleth',
#   'windbergen',
#   'winnert',
#   'witzhave',
#   'wohlde',
#   'wrohm',
#   'woehrden'],
#  'Thueringen': ['abtsbessingen',
#   'ahlstaedt',
#   'alkersleben',
#   'alperstedt',
#   'altenberga',
#   'altenbeuthen',
#   'altenburg',
#   'altengottern',
#   'altersbach',
#   'altkirchen',
#   'andenhausen',
#   'andisleben',
#   'angelroda',
#   'apolda',
#   'arenshausen',
#   'arnsgereuth',
#   'arnstadt',
#   'aschenhausen',
#   'auerstedt',
#   'auma',
#   'bachfeld',
#   'badberka',
#   'badblankenburg',
#   'badcolberg-heldburg',
#   'badklosterlausnitz',
#   'badkoestritz',
#   'badsalzungen',
#   'badtennstedt',
#   'badra',
#   'ballstedt',
#   'ballstaedt',
#   'barchfeld',
#   'bauerbach',
#   'bechstedtstrass',
#   'beinerstadt',
#   'benshausen',
#   'berga',
#   'berlingerode',
#   'bermbach',
#   'bethenhausen',
#   'beuren',
#   'bilzingsleben',
#   'birkenhuegel',
#   'blankenhain',
#   'bleicherode',
#   'bocka',
#   'bockstadt',
#   'bodelwitz',
#   'braunichswalde',
#   'brotterode',
#   'bucha',
#   'buchbach',
#   'burgk',
#   'buettstedt',
#   'christes',
#   'crawinkel',
#   'creuzburg',
#   'crimla',
#   'crispendorf',
#   'cursdorf',
#   'dermbach',
#   'dingelstaedt',
#   'doebritschen',
#   'doeschnitz',
#   'eisenach',
#   'elgersburg',
#   'elleben',
#   'ellrich',
#   'erfurt',
#   'flarchheim',
#   'floh-seligenthal',
#   'fockendorf',
#   'frauenwald',
#   'foeritz',
#   'gangloffsoemmern',
#   'gefell',
#   'gehlberg',
#   'gehren',
#   'gera',
#   'gerstungen',
#   'goldisthal',
#   'gotha',
#   'greiz',
#   'graefendorf',
#   'goehren-doehlen',
#   'goessnitz',
#   'guenstedt',
#   'hain',
#   'hohenfelden',
#   'hohenleuben',
#   'ilmenau',
#   'jena',
#   'kirschkau',
#   'koerner',
#   'lehesten',
#   'lichte',
#   'lucka',
#   'luisenthal',
#   'meiningen',
#   'mengersgereuth-haemmern',
#   'metzels',
#   'meuselwitz',
#   'mohlsdorf',
#   'muehlhausen/thueringen',
#   'nordhausen',
#   'ostramondra',
#   'rudolstadt',
#   'ruhla',
#   'saalfeld/saale',
#   'schwarzburg',
#   'seebach',
#   'sondershausen',
#   'sonneberg',
#   'stadtlengsfeld',
#   'stuetzerbach',
#   'suhl',
#   'tanna',
#   'trusetal',
#   'unterwellenborn',
#   'veilsdorf',
#   'weimar',
#   'zella-mehlis']}

# %% [markdown]
# __Insert corresponding states into the dataframe in new column__

# %%
def match_cities_to_states(dataframe):
    #For each entry in the dataframe
    for city in dataframe.index.values:
        #For every key in the dict
        for key in dict_state_to_city.keys():
            #And every element per key
            for element in dict_state_to_city[key]:
                #If the element (value of a cetain key) is equal to the city name
                if element==city:
                    #get the index of this city entry in the dataframe
                    idx=dataframe[dataframe.index==city].index
                    #set on the index "idx" and the column "state" the key
                    dataframe.loc[idx,"state"]=key
                else:
                    pass
    return dataframe

# %%
df_raw=match_cities_to_states(df_raw)

# %%
df_raw.head()
# Out:
#            2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# aach        NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.68  5.14  5.68  5.97
# aachen      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.95  7.19  7.63
# aalen       NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.90  6.10  6.15  6.39
# aarbergen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.20  5.46  5.17
# abensberg   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.53  6.05  5.81
#
#            2013  2014  2015  2016  2017                state
# aach       5.09  6.53  6.37  6.69  7.04      Rheinland-Pfalz
# aachen     7.92  8.16  8.30  8.64  8.87  Nordrhein-Westfalen
# aalen      6.73  7.12  7.62  8.38  8.66   Baden-Wuerttemberg
# aarbergen  4.97  5.13  5.17  5.60  5.71               Hessen
# abensberg  5.96  5.93  6.87  8.01  7.90               Bayern

# %%
df_raw.astype({2010: 'float32',2017: 'float32'})
# Out:
#                2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# aach            NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.68  5.14  5.68
# aachen          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.95  7.19
# aalen           NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.90  6.10  6.15
# aarbergen       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.20  5.46
# abensberg       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.53  6.05
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# zusmarshausen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.55  5.72
# zweibruecken    NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.58  4.88  4.93
# zwenkau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.02  4.97
# zwickau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.80  4.84
# zwingenberg     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  7.62  7.50
#
#                2012  2013  2014  2015  2016  2017                state
# aach           5.97  5.09  6.53  6.37  6.69  7.04      Rheinland-Pfalz
# aachen         7.63  7.92  8.16  8.30  8.64  8.87  Nordrhein-Westfalen
# aalen          6.39  6.73  7.12  7.62  8.38  8.66   Baden-Wuerttemberg
# aarbergen      5.17  4.97  5.13  5.17  5.60  5.71               Hessen
# abensberg      5.81  5.96  5.93  6.87  8.01  7.90               Bayern
# ...             ...   ...   ...   ...   ...   ...                  ...
# zusmarshausen  6.00  6.33  6.17  6.08  7.51  7.68               Bayern
# zweibruecken   5.10  5.07  5.14  5.27  5.39  5.71      Rheinland-Pfalz
# zwenkau        5.03  5.19  5.40  5.35  5.59  6.29              Sachsen
# zwickau        4.93  4.99  5.09  5.10  5.23  5.43              Sachsen
# zwingenberg    7.26  7.92  8.01  7.92  7.77  8.66               Hessen
#
# [2469 rows x 17 columns]

# %%
df_raw
# Out:
#                2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# aach            NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.68  5.14  5.68
# aachen          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.95  7.19
# aalen           NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.90  6.10  6.15
# aarbergen       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.20  5.46
# abensberg       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.53  6.05
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# zusmarshausen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.55  5.72
# zweibruecken    NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.58  4.88  4.93
# zwenkau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.02  4.97
# zwickau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.80  4.84
# zwingenberg     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  7.62  7.50
#
#                2012  2013  2014  2015  2016  2017                state
# aach           5.97  5.09  6.53  6.37  6.69  7.04      Rheinland-Pfalz
# aachen         7.63  7.92  8.16  8.30  8.64  8.87  Nordrhein-Westfalen
# aalen          6.39  6.73  7.12  7.62  8.38  8.66   Baden-Wuerttemberg
# aarbergen      5.17  4.97  5.13  5.17  5.60  5.71               Hessen
# abensberg      5.81  5.96  5.93  6.87  8.01  7.90               Bayern
# ...             ...   ...   ...   ...   ...   ...                  ...
# zusmarshausen  6.00  6.33  6.17  6.08  7.51  7.68               Bayern
# zweibruecken   5.10  5.07  5.14  5.27  5.39  5.71      Rheinland-Pfalz
# zwenkau        5.03  5.19  5.40  5.35  5.59  6.29              Sachsen
# zwickau        4.93  4.99  5.09  5.10  5.23  5.43              Sachsen
# zwingenberg    7.26  7.92  8.01  7.92  7.77  8.66               Hessen
#
# [2469 rows x 17 columns]

# %% [markdown]
# __Now we want to get a grouped dataframe that contains means and standard deviations per state for the rental prices__

# %%
df_grouped=df_raw.groupby("state").mean()

# %%
df_grouped.head()
# Out:
#                     2002  2003  2004  2005  2006  2007  2008      2009  \
# state
# Baden-Wuerttemberg   NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.759643
# Bayern               NaN   NaN   NaN   NaN   NaN   NaN   4.6  5.922059
# Berlin               NaN   NaN   NaN   NaN   NaN   NaN   NaN  8.430000
# Brandenburg          NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN
# Bremen               NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.490000
#
#                         2010      2011      2012      2013      2014  \
# state
# Baden-Wuerttemberg  6.612102  6.752458  6.846000  7.060615  7.221397
# Bayern              6.340102  6.434101  6.655681  6.807259  7.004533
# Berlin              6.980000  7.260000  7.700000  8.270000  8.860000
# Brandenburg         5.736667  6.031250  6.136829  6.513500  6.556829
# Bremen              5.405000  5.650000  5.935000  6.120000  6.230000
#
#                         2015      2016       2017
# state
# Baden-Wuerttemberg  7.507043  7.969811   8.456354
# Bayern              7.284161  7.755324   8.169422
# Berlin              9.110000  9.830000  10.880000
# Brandenburg         6.520500  6.699268   7.252439
# Bremen              6.285000  6.705000   7.135000

# %%
df_raw
# Out:
#                2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# aach            NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.68  5.14  5.68
# aachen          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.95  7.19
# aalen           NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.90  6.10  6.15
# aarbergen       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.20  5.46
# abensberg       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.53  6.05
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# zusmarshausen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.55  5.72
# zweibruecken    NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.58  4.88  4.93
# zwenkau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  5.02  4.97
# zwickau         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  4.80  4.84
# zwingenberg     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  7.62  7.50
#
#                2012  2013  2014  2015  2016  2017                state
# aach           5.97  5.09  6.53  6.37  6.69  7.04      Rheinland-Pfalz
# aachen         7.63  7.92  8.16  8.30  8.64  8.87  Nordrhein-Westfalen
# aalen          6.39  6.73  7.12  7.62  8.38  8.66   Baden-Wuerttemberg
# aarbergen      5.17  4.97  5.13  5.17  5.60  5.71               Hessen
# abensberg      5.81  5.96  5.93  6.87  8.01  7.90               Bayern
# ...             ...   ...   ...   ...   ...   ...                  ...
# zusmarshausen  6.00  6.33  6.17  6.08  7.51  7.68               Bayern
# zweibruecken   5.10  5.07  5.14  5.27  5.39  5.71      Rheinland-Pfalz
# zwenkau        5.03  5.19  5.40  5.35  5.59  6.29              Sachsen
# zwickau        4.93  4.99  5.09  5.10  5.23  5.43              Sachsen
# zwingenberg    7.26  7.92  8.01  7.92  7.77  8.66               Hessen
#
# [2469 rows x 17 columns]

# %% [markdown]
# __Now we are interested in the standard dev. of states containing certain city data. We need that as errorbars for our plots of state data later on. Of course all year to year comparisons should be inflation adjusted.__

# %%
df_grouped
# Out:
#                             2002      2003      2004      2005      2006  \
# state
# Baden-Wuerttemberg           NaN       NaN       NaN       NaN       NaN
# Bayern                       NaN       NaN       NaN       NaN       NaN
# Berlin                       NaN       NaN       NaN       NaN       NaN
# Brandenburg                  NaN       NaN       NaN       NaN       NaN
# Bremen                       NaN       NaN       NaN       NaN       NaN
# Hamburg                      NaN       NaN       NaN       NaN       NaN
# Hessen                       NaN       NaN       NaN       NaN       NaN
# Mecklenburg-Vorpommern       NaN       NaN       NaN       NaN       NaN
# Niedersachsen           5.481667  5.343333  5.791538  5.493077  5.516667
# Nordrhein-Westfalen          NaN       NaN       NaN       NaN       NaN
# Rheinland-Pfalz              NaN       NaN       NaN       NaN       NaN
# Saarland                     NaN       NaN       NaN       NaN       NaN
# Sachsen                      NaN       NaN       NaN       NaN       NaN
# Sachsen-Anhalt               NaN       NaN       NaN       NaN       NaN
# Schleswig-Holstein           NaN       NaN       NaN       NaN       NaN
# Thueringen                   NaN       NaN       NaN       NaN       NaN
#
#                             2007      2008      2009      2010      2011  \
# state
# Baden-Wuerttemberg           NaN       NaN  6.759643  6.612102  6.752458
# Bayern                       NaN  4.600000  5.922059  6.340102  6.434101
# Berlin                       NaN       NaN  8.430000  6.980000  7.260000
# Brandenburg                  NaN       NaN       NaN  5.736667  6.031250
# Bremen                       NaN       NaN  6.490000  5.405000  5.650000
# Hamburg                      NaN       NaN       NaN  9.600000  9.910000
# Hessen                       NaN  4.660000  5.433750  6.073868  6.198645
# Mecklenburg-Vorpommern  4.360000  7.140000  5.995000  5.522083  5.649750
# Niedersachsen           5.352667  5.500696  5.347500  5.338274  5.412466
# Nordrhein-Westfalen          NaN  4.461429  5.584444  5.503555  5.574533
# Rheinland-Pfalz              NaN       NaN  5.590423  5.654706  5.777600
# Saarland                     NaN       NaN  5.075000  5.292414  5.285172
# Sachsen                      NaN  7.070000  5.218000  4.796970  4.987404
# Sachsen-Anhalt               NaN  4.500000       NaN  4.748444  4.845556
# Schleswig-Holstein           NaN  3.090000  7.376364  6.488725  6.593390
# Thueringen                   NaN       NaN       NaN  5.295217  5.204762
#
#                              2012       2013       2014       2015       2016  \
# state
# Baden-Wuerttemberg       6.846000   7.060615   7.221397   7.507043   7.969811
# Bayern                   6.655681   6.807259   7.004533   7.284161   7.755324
# Berlin                   7.700000   8.270000   8.860000   9.110000   9.830000
# Brandenburg              6.136829   6.513500   6.556829   6.520500   6.699268
# Bremen                   5.935000   6.120000   6.230000   6.285000   6.705000
# Hamburg                 10.320000  10.560000  10.770000  10.770000  11.170000
# Hessen                   6.368037   6.463178   6.631495   6.794554   7.041651
# Mecklenburg-Vorpommern   5.686923   5.740750   5.714000   6.001500   6.222500
# Niedersachsen            5.510959   5.668919   5.846606   6.073333   6.375822
# Nordrhein-Westfalen      5.671419   5.737309   5.883667   5.984785   6.235567
# Rheinland-Pfalz          5.702500   5.837132   6.029444   6.209313   6.468077
# Saarland                 5.500345   5.754138   5.815862   5.980000   6.216552
# Sachsen                  4.992233   5.151359   5.239346   5.204464   5.398182
# Sachsen-Anhalt           4.811333   4.977609   4.860217   5.054043   5.238085
# Schleswig-Holstein       6.625238   6.717840   6.781587   6.942623   7.358049
# Thueringen               5.206923   5.344651   5.493571   5.509149   5.642128
#
#                              2017
# state
# Baden-Wuerttemberg       8.456354
# Bayern                   8.169422
# Berlin                  10.880000
# Brandenburg              7.252439
# Bremen                   7.135000
# Hamburg                 11.870000
# Hessen                   7.492465
# Mecklenburg-Vorpommern   6.501250
# Niedersachsen            6.542978
# Nordrhein-Westfalen      6.520132
# Rheinland-Pfalz          6.763969
# Saarland                 6.342069
# Sachsen                  5.556549
# Sachsen-Anhalt           5.416596
# Schleswig-Holstein       7.534016
# Thueringen               6.302979

# %%
mean_infl_per_year_full=np.mean(infl_lst_full)
mean_infl_per_year_part=np.mean(infl_lst_part)
#Sort by means for 2010
df_gr=df_grouped.drop(df_grouped.columns.difference(["index","state",2010,2017]), axis=1)
df_gr.sort_values(by=[2010], ascending=True, inplace=True)
#Create new df where we calculate calculate stds for each state and save it to the new column "std_2010"
df_std_2010=df_raw.groupby("state").agg({2010:np.std}).rename({2010:"std_2010"},axis=1)

#Same for 2017 data
df_gr=df_grouped.drop(df_grouped.columns.difference(["state",2010,2017]), axis=1)
df_gr.sort_values(by=[2017], ascending=True, inplace=True)
df_std_2017=df_raw.groupby("state").agg({2017:np.std}).rename({2017:"std_2017"},axis=1)

#Use mean inflation rate to get inflation adjustment only for 2017
df_std_2017["std_2017_part"]=df_std_2017["std_2017"].apply(lambda x: x/mean_infl_per_year_part**7)
df_std_2017["std_2017"]=df_std_2017["std_2017"].apply(lambda x: x/mean_infl_per_year_full**7)

df_std_2017["mean_2017_part"]=df_gr[2017].apply(lambda x: x/mean_infl_per_year_part**7)
df_std_2017["mean_2017_full"]=df_gr[2017].apply(lambda x: x/mean_infl_per_year_full**7)

# #Merge to 2010/2017 dataframes and generate df_grouped 
df_temp=pd.merge(df_gr,df_std_2010, on="state", how="inner")
df_grouped=pd.merge(df_temp,df_std_2017, on="state", how="inner")

# %%
df_grouped=df_grouped.round(2)

# %%
df_grouped
# Out:
#                         2010   2017  std_2010  std_2017  std_2017_part  \
# state
# Sachsen-Anhalt          4.75   5.42      0.96      0.59           0.60
# Sachsen                 4.80   5.56      0.76      0.73           0.75
# Thueringen              5.30   6.30      0.80      2.94           2.99
# Saarland                5.29   6.34      0.65      0.65           0.66
# Mecklenburg-Vorpommern  5.52   6.50      0.83      1.38           1.40
# Nordrhein-Westfalen     5.50   6.52      0.79      0.94           0.95
# Niedersachsen           5.34   6.54      1.00      1.24           1.26
# Rheinland-Pfalz         5.65   6.76      1.05      1.31           1.33
# Bremen                  5.40   7.14      1.27      1.82           1.85
# Brandenburg             5.74   7.25      1.16      1.39           1.41
# Hessen                  6.07   7.49      1.52      1.62           1.65
# Schleswig-Holstein      6.49   7.53      1.35      1.23           1.25
# Bayern                  6.34   8.17      1.78      1.95           1.99
# Baden-Wuerttemberg      6.61   8.46      1.26      1.41           1.44
# Berlin                  6.98  10.88       NaN       NaN            NaN
# Hamburg                 9.60  11.87       NaN       NaN            NaN
#
#                         mean_2017_part  mean_2017_full
# state
# Sachsen-Anhalt                    5.05            4.96
# Sachsen                           5.18            5.09
# Thueringen                        5.87            5.77
# Saarland                          5.91            5.81
# Mecklenburg-Vorpommern            6.06            5.95
# Nordrhein-Westfalen               6.08            5.97
# Niedersachsen                     6.10            5.99
# Rheinland-Pfalz                   6.30            6.20
# Bremen                            6.65            6.54
# Brandenburg                       6.76            6.64
# Hessen                            6.98            6.86
# Schleswig-Holstein                7.02            6.90
# Bayern                            7.61            7.48
# Baden-Wuerttemberg                7.88            7.75
# Berlin                           10.14            9.97
# Hamburg                          11.06           10.87

# %% [markdown]
# __Now we save the dataframes to use it in another file and provide them as sources__

# %%
df_grouped.to_csv("data\\csv\\grouped.csv")
df_raw.to_csv("data\\csv\\raw.csv")
df_calc.to_csv("data\\csv\\calc_raw.csv")

# %% [markdown]
# __Getting inflation data from statista and calculate adjustment for each year in the dataframe__

# %%
means_raw=df_calc["Mean in $\\mathrm{\\frac{EUR}{m^2}}$"][8:].values
stds_raw=df_calc["SD in $\\mathrm{\\frac{EUR}{m^2}}$"][8:].values

# %% [markdown]
# __Save inflation adjustment for averages and standard devs.__

# %%
infl_adjusted_means_full=inflation_adjustment(infl_lst_full,means_raw)
infl_adjusted_std_full=inflation_adjustment(infl_lst_full,stds_raw)

# %%
savetxt('data\\csv\\infl_adjusted_means_full.csv', infl_adjusted_means_full, delimiter=',')
savetxt('data\\csv\\infl_adjusted_std_full.csv', infl_adjusted_std_full, delimiter=',')
savetxt('data\\csv\\infl_lst_full.csv', infl_lst_full, delimiter=',')
savetxt('data\\csv\\means_raw.csv', means_raw, delimiter=',')

# %% [markdown]
# __Additional table for the paper__

# %%
count_17=pd.DataFrame(df_raw.groupby(["state"]).count()[2017])
count_10=pd.DataFrame(df_raw.groupby(["state"]).count()[2010])
df_count=pd.merge(count_17, count_10,on=["state"], how="inner")

# %%
df_count=df_count.rename({2017: "data points 2017", 2010: "data points 2010"}, axis=1)

# %%
with open('..\\paper\\Table_bavarian_cities.tex','w') as tf:
    tf.write(df_count.to_latex(escape=False))

# %%
df_calc
# Out:
#       aach  aachen  aalen  aarbergen  abensberg  absberg  abstatt  achim  \
# 2002   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2003   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2004   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2005   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2006   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2007   NaN     NaN    NaN        NaN        NaN      NaN      NaN    NaN
# 2008   NaN     NaN    NaN        NaN        NaN      NaN      NaN   6.10
# 2009  6.68     NaN   5.90        NaN        NaN      NaN      NaN    NaN
# 2010  5.14    6.95   6.10       5.20       4.53     4.72     7.11   5.64
# 2011  5.68    7.19   6.15       5.46       6.05     4.51     6.56   5.89
# 2012  5.97    7.63   6.39       5.17       5.81     5.19     7.34   6.21
# 2013  5.09    7.92   6.73       4.97       5.96     4.80     7.99   6.22
# 2014  6.53    8.16   7.12       5.13       5.93      NaN     7.81   6.29
# 2015  6.37    8.30   7.62       5.17       6.87     6.85     8.21   6.46
# 2016  6.69    8.64   8.38       5.60       8.01     6.56     8.94   6.96
# 2017  7.04    8.87   8.66       5.71       7.90     7.07     8.89   7.47
#
#       achtrup  adelschlag  ...  zschorlau  zuelpich  zusmarshausen  \
# 2002      NaN         NaN  ...        NaN       NaN            NaN
# 2003      NaN         NaN  ...        NaN       NaN            NaN
# 2004      NaN         NaN  ...        NaN       NaN            NaN
# 2005      NaN         NaN  ...        NaN       NaN            NaN
# 2006      NaN         NaN  ...        NaN       NaN            NaN
# 2007      NaN         NaN  ...        NaN       NaN            NaN
# 2008      NaN         NaN  ...        NaN       NaN            NaN
# 2009      NaN         NaN  ...        NaN       NaN            NaN
# 2010     5.45         NaN  ...       4.11      5.27           5.55
# 2011     4.99         NaN  ...       5.17      5.35           5.72
# 2012     5.03        5.24  ...       4.50      5.30           6.00
# 2013     5.34        5.97  ...       4.27      5.47           6.33
# 2014     5.16        6.21  ...       4.43      5.66           6.17
# 2015     5.48        8.11  ...       4.68      5.69           6.08
# 2016     6.16        6.74  ...       5.35      6.01           7.51
# 2017     6.17        8.16  ...       5.55      6.14           7.68
#
#       zweibruecken  zwenkau  zwickau  zwingenberg  \
# 2002           NaN      NaN      NaN          NaN
# 2003           NaN      NaN      NaN          NaN
# 2004           NaN      NaN      NaN          NaN
# 2005           NaN      NaN      NaN          NaN
# 2006           NaN      NaN      NaN          NaN
# 2007           NaN      NaN      NaN          NaN
# 2008           NaN      NaN      NaN          NaN
# 2009          4.58      NaN      NaN          NaN
# 2010          4.88     5.02     4.80         7.62
# 2011          4.93     4.97     4.84         7.50
# 2012          5.10     5.03     4.93         7.26
# 2013          5.07     5.19     4.99         7.92
# 2014          5.14     5.40     5.09         8.01
# 2015          5.27     5.35     5.10         7.92
# 2016          5.39     5.59     5.23         7.77
# 2017          5.71     6.29     5.43         8.66
#
#       Mean in $\mathrm{\frac{EUR}{m^2}}$  SD in $\mathrm{\frac{EUR}{m^2}}$  \
# 2002                            5.481667                          0.739063
# 2003                            5.343333                          0.782588
# 2004                            5.791538                          0.974315
# 2005                            5.493077                          0.768229
# 2006                            5.516667                          0.704847
# 2007                            5.290625                          0.850665
# 2008                            5.390226                          1.103880
# 2009                            6.253333                          1.458711
# 2010                            5.964045                          1.448575
# 2011                            6.060828                          1.424802
# 2012                            6.173628                          1.510291
# 2013                            6.317492                          1.590471
# 2014                            6.471769                          1.609157
# 2015                            6.669967                          1.595979
# 2016                            7.019056                          1.692820
# 2017                            7.369984                          1.886425
#
#       Historical data points
# 2002                       8
# 2003                      11
# 2004                      15
# 2005                      15
# 2006                      17
# 2007                      18
# 2008                     135
# 2009                     410
# 2010                    2254
# 2011                    2382
# 2012                    2392
# 2013                    2406
# 2014                    2399
# 2015                    2458
# 2016                    2449
# 2017                    2471
#
# [16 rows x 2472 columns]
